# %% [markdown]
# # 20220601_SAR Linear Regression_Aman

# %%
# (Aman) Some links for learning Spatially Adjusted Regression
#http://www.bisolutions.us/A-Brief-Introduction-to-Spatial-Regression.php
#https://crd230.github.io/lab8.html#

# %% [markdown]
# ## Spatially Adjusted Regression - Linear Regression
#
# Ordinary Least Squares vs Spatial Simultaneous Autoregressive Models
#
# In this practice, it is assumed that we are working under the normal probability model. The goals of this practice are to:
#
# a) evaluate a standard OLS regression using a continuous dependent variable when spatial autocorrelation may be present, and
#
# b) evaluate the same relationships given the ability to adjust for spatial autocorrelation using the rho term obtained from a simultaneous autoregressive error model.

# %% [markdown]
# ### Load relevant libraries
#
# Documentation for the R libraries used in this notebook can be found at:
#
#
#   - [rgdal library](https://web.dsa.missouri.edu/static/PDF/R/rgdal.pdf)
#
#   - [classInt library](https://web.dsa.missouri.edu/static/PDF/R/classInt.pdf)
#
#   - [spdep library](https://web.dsa.missouri.edu/static/PDF/R/spdep.pdf)
#
#   - [RColorBrewer library](https://web.dsa.missouri.edu/static/PDF/R/RColorBrewer.pdf)
#
#   - [geoR library](https://web.dsa.missouri.edu/static/PDF/R/geoR.pdf)
#
#   - [car library](https://web.dsa.missouri.edu/static/PDF/R/car.pdf)
#
#   - [MASS library](https://web.dsa.missouri.edu/static/PDF/R/MASS.pdf)

# %%
## Load relevant R packages.
inLibraries = list('repr','rgdal','spdep','spatialreg','classInt','car','RColorBrewer','MASS','geoR')
for (rpack in inLibraries) {
  if (is.element(rpack,installed.packages()[,1])){           
      #Load the library into R
      suppressMessages(library(rpack,character.only = TRUE))
    }
    else {
        print(paste("Warning:  ",rpack," is not an installed package"))
    }
}

## Resize plot area.
options(repr.plot.width=6, repr.plot.height=6)

# %% [markdown]
# ## Sentiment Data
#
# Reading the compiled dataset of the sentiment rankings and urban counterpart classification

# %%
## Read in the featureclass.
inFeatures <- readOGR(dsn="C:/Users/ja2qm/MIZZOU/_MotherFolderAmanWorks/Aman thesis works/_1_FinalTopic/_CAADRIA2022/Paper_2/SensingTheCity_Stat_R_TimScript/ScriptExperiment_Aman/dataset", layer="SensingTheCity")
# Out:
# OGR data source with driver: ESRI Shapefile
# Source: "C:\Users\ja2qm\MIZZOU\_MotherFolderAmanWorks\Aman thesis works\_1_FinalTopic\_CAADRIA2022\Paper_2\SensingTheCity_Stat_R_TimScript\ScriptExperiment_Aman\dataset", layer: "SensingTheCity"
# with 47110 features
# It has 36 fields
# Integer64 fields read as strings:  OID_ Date_Month Date_Day Date_Year Time_Hour Time_Minut Time_Secon Rank_0_1

# %% [markdown]
# ## Subset Features
#
# We'll subset the data based on specific month and date (use Date_Month & Date_Year)

# %%
#Subset of the data using the month and year
inFeaturesSubsetA1 <- inFeatures[grep("9", inFeatures@data$Date_Month), ]
inFeaturesSubsetA <- inFeaturesSubsetA1[grep("2021", inFeaturesSubsetA1@data$Date_Year), ]
inFeaturesSubsetA
# Out:
# Registered S3 method overwritten by 'geojsonsf':
#   method        from
#   print.geojson geojson
#                 coordinates  OID_       Date Date_Month Date_Day Date_Year
# 14    (-92.32741, 38.95017)    13 2021/09/28          9       28      2021
# 15    (-92.32741, 38.95017)    14 2021/09/27          9       27      2021
# 16    (-92.32741, 38.95017)    15 2021/09/26          9       26      2021
# 17    (-92.32741, 38.95017)    16 2021/09/24          9       24      2021
# 18    (-92.32741, 38.95017)    17 2021/09/23          9       23      2021
# 19    (-92.32741, 38.95017)    18 2021/09/18          9       18      2021
# 20    (-92.32741, 38.95017)    19 2021/09/18          9       18      2021
# 21    (-92.32741, 38.95017)    20 2021/09/16          9       16      2021
# 22    (-92.32741, 38.95017)    21 2021/09/01          9        1      2021
# 23    (-92.32741, 38.95017)    22 2021/09/01          9        1      2021
# 114   (-92.33473, 38.94798)   218 2021/09/04          9        4      2021
# 229   (-92.32602, 38.94564)   333 2021/09/09          9        9      2021
# 526   (-92.33268, 38.95082)   630 2021/09/10          9       10      2021
# 527   (-92.33268, 38.95082)   631 2021/09/01          9        1      2021
# 1685   (-92.3311, 38.94047)  1789 2021/09/21          9       21      2021
# 1686   (-92.3311, 38.94047)  1790 2021/09/15          9       15      2021
# 1687   (-92.3311, 38.94047)  1791 2021/09/08          9        8      2021
# 1688   (-92.3311, 38.94047)  1792 2021/09/05          9        5      2021
# 1689   (-92.3311, 38.94047)  1793 2021/09/03          9        3      2021
# 1690   (-92.3311, 38.94047)  1794 2021/09/03          9        3      2021
# 2857  (-92.32726, 38.94682)  2961 2021/09/30          9       30      2021
# 2858  (-92.32726, 38.94682)  2962 2021/09/20          9       20      2021
# 2859  (-92.32726, 38.94682)  2963 2021/09/19          9       19      2021
# 2860  (-92.32726, 38.94682)  2964 2021/09/12          9       12      2021
# 2861  (-92.32726, 38.94682)  2965 2021/09/10          9       10      2021
# 2862  (-92.32726, 38.94682)  2966 2021/09/10          9       10      2021
# 2863  (-92.32726, 38.94682)  2967 2021/09/09          9        9      2021
# 2864  (-92.32726, 38.94682)  2968 2021/09/08          9        8      2021
# 2865  (-92.32726, 38.94682)  2969 2021/09/08          9        8      2021
# 2866  (-92.32726, 38.94682)  2970 2021/09/07          9        7      2021
# 2867  (-92.32726, 38.94682)  2971 2021/09/05          9        5      2021
# 2868  (-92.32726, 38.94682)  2972 2021/09/02          9        2      2021
# 3843  (-92.33162, 38.94286)  3947 2021/09/30          9       30      2021
# 3844  (-92.33162, 38.94286)  3948 2021/09/28          9       28      2021
# 3845  (-92.33162, 38.94286)  3949 2021/09/27          9       27      2021
# 3846  (-92.33162, 38.94286)  3950 2021/09/26          9       26      2021
# 3847  (-92.33162, 38.94286)  3951 2021/09/21          9       21      2021
# 3848  (-92.33162, 38.94286)  3952 2021/09/20          9       20      2021
# 3849  (-92.33162, 38.94286)  3953 2021/09/20          9       20      2021
# 3850  (-92.33162, 38.94286)  3954 2021/09/20          9       20      2021
# 3851  (-92.33162, 38.94286)  3955 2021/09/20          9       20      2021
# 3852  (-92.33162, 38.94286)  3956 2021/09/19          9       19      2021
# 3853  (-92.33162, 38.94286)  3957 2021/09/19          9       19      2021
# 3854  (-92.33162, 38.94286)  3958 2021/09/19          9       19      2021
# 3855  (-92.33162, 38.94286)  3959 2021/09/19          9       19      2021
# 3856  (-92.33162, 38.94286)  3960 2021/09/18          9       18      2021
# 3857  (-92.33162, 38.94286)  3961 2021/09/18          9       18      2021
# 3858  (-92.33162, 38.94286)  3962 2021/09/18          9       18      2021
# 3859  (-92.33162, 38.94286)  3963 2021/09/18          9       18      2021
# 3860  (-92.33162, 38.94286)  3964 2021/09/18          9       18      2021
# 3861  (-92.33162, 38.94286)  3965 2021/09/17          9       17      2021
# 3862  (-92.33162, 38.94286)  3966 2021/09/17          9       17      2021
# 3863  (-92.33162, 38.94286)  3967 2021/09/17          9       17      2021
# 3864  (-92.33162, 38.94286)  3968 2021/09/17          9       17      2021
# 3865  (-92.33162, 38.94286)  3969 2021/09/17          9       17      2021
# 3866  (-92.33162, 38.94286)  3970 2021/09/17          9       17      2021
# 3867  (-92.33162, 38.94286)  3971 2021/09/17          9       17      2021
# 3868  (-92.33162, 38.94286)  3972 2021/09/17          9       17      2021
# 3869  (-92.33162, 38.94286)  3973 2021/09/17          9       17      2021
# 3870  (-92.33162, 38.94286)  3974 2021/09/17          9       17      2021
# 3871  (-92.33162, 38.94286)  3975 2021/09/17          9       17      2021
# 3872  (-92.33162, 38.94286)  3976 2021/09/17          9       17      2021
# 3873  (-92.33162, 38.94286)  3977 2021/09/17          9       17      2021
# 3874  (-92.33162, 38.94286)  3978 2021/09/09          9        9      2021
# 3875  (-92.33162, 38.94286)  3979 2021/09/05          9        5      2021
# 3876  (-92.33162, 38.94286)  3980 2021/09/04          9        4      2021
# 3877  (-92.33162, 38.94286)  3981 2021/09/04          9        4      2021
# 5068   (-92.3314, 38.94428)  5172 2021/09/02          9        2      2021
# 5124  (-92.32895, 38.95084)  5228 2021/09/18          9       18      2021
# 5125  (-92.32895, 38.95084)  5229 2021/09/18          9       18      2021
# 5126  (-92.32895, 38.95084)  5230 2021/09/16          9       16      2021
# 5127  (-92.32895, 38.95084)  5231 2021/09/08          9        8      2021
# 5128  (-92.32895, 38.95084)  5232 2021/09/07          9        7      2021
# 5129  (-92.32895, 38.95084)  5233 2021/09/07          9        7      2021
# 6465  (-92.33113, 38.95146)  6569 2021/09/29          9       29      2021
# 6466  (-92.33113, 38.95146)  6570 2021/09/26          9       26      2021
# 6467  (-92.33113, 38.95146)  6571 2021/09/25          9       25      2021
# 6468  (-92.33113, 38.95146)  6572 2021/09/20          9       20      2021
# 6469  (-92.33113, 38.95146)  6573 2021/09/20          9       20      2021
# 6470  (-92.33113, 38.95146)  6574 2021/09/19          9       19      2021
# 6471  (-92.33113, 38.95146)  6575 2021/09/13          9       13      2021
# 6472  (-92.33113, 38.95146)  6576 2021/09/10          9       10      2021
# 6473  (-92.33113, 38.95146)  6577 2021/09/08          9        8      2021
# 6474  (-92.33113, 38.95146)  6578 2021/09/08          9        8      2021
# 6475  (-92.33113, 38.95146)  6579 2021/09/08          9        8      2021
# 6476  (-92.33113, 38.95146)  6580 2021/09/08          9        8      2021
# 6477  (-92.33113, 38.95146)  6581 2021/09/07          9        7      2021
# 7820  (-92.33415, 38.95252)  7924 2021/09/28          9       28      2021
# 7821  (-92.33415, 38.95252)  7925 2021/09/14          9       14      2021
# 7822  (-92.33415, 38.95252)  7926 2021/09/06          9        6      2021
# 7986   (-92.3273, 38.95066)  8097 2021/09/27          9       27      2021
# 7987   (-92.3273, 38.95066)  8098 2021/09/27          9       27      2021
# 7988   (-92.3273, 38.95066)  8099 2021/09/02          9        2      2021
# 7989   (-92.3273, 38.95066)  8100 2021/09/02          9        2      2021
# 9482  (-92.32817, 38.95273)  9593 2021/09/30          9       30      2021
# 9483  (-92.32817, 38.95273)  9594 2021/09/30          9       30      2021
# 9484  (-92.32817, 38.95273)  9595 2021/09/30          9       30      2021
# 9485  (-92.32817, 38.95273)  9596 2021/09/30          9       30      2021
# 9486  (-92.32817, 38.95273)  9597 2021/09/30          9       30      2021
# 9487  (-92.32817, 38.95273)  9598 2021/09/28          9       28      2021
# 9488  (-92.32817, 38.95273)  9599 2021/09/27          9       27      2021
# 9489  (-92.32817, 38.95273)  9600 2021/09/27          9       27      2021
# 9490  (-92.32817, 38.95273)  9601 2021/09/26          9       26      2021
# 9491  (-92.32817, 38.95273)  9602 2021/09/26          9       26      2021
# 9492  (-92.32817, 38.95273)  9603 2021/09/26          9       26      2021
# 9493  (-92.32817, 38.95273)  9604 2021/09/26          9       26      2021
# 9494  (-92.32817, 38.95273)  9605 2021/09/26          9       26      2021
# 9495  (-92.32817, 38.95273)  9606 2021/09/26          9       26      2021
# 9496  (-92.32817, 38.95273)  9607 2021/09/25          9       25      2021
# 9497  (-92.32817, 38.95273)  9608 2021/09/25          9       25      2021
# 9498  (-92.32817, 38.95273)  9609 2021/09/25          9       25      2021
# 9499  (-92.32817, 38.95273)  9610 2021/09/24          9       24      2021
# 9500  (-92.32817, 38.95273)  9611 2021/09/23          9       23      2021
# 9501  (-92.32817, 38.95273)  9612 2021/09/23          9       23      2021
# 9502  (-92.32817, 38.95273)  9613 2021/09/23          9       23      2021
# 9503  (-92.32817, 38.95273)  9614 2021/09/23          9       23      2021
# 9504  (-92.32817, 38.95273)  9615 2021/09/21          9       21      2021
# 9505  (-92.32817, 38.95273)  9616 2021/09/21          9       21      2021
# 9506  (-92.32817, 38.95273)  9617 2021/09/20          9       20      2021
# 9507  (-92.32817, 38.95273)  9618 2021/09/20          9       20      2021
# 9508  (-92.32817, 38.95273)  9619 2021/09/19          9       19      2021
# 9509  (-92.32817, 38.95273)  9620 2021/09/18          9       18      2021
# 9510  (-92.32817, 38.95273)  9621 2021/09/17          9       17      2021
# 9511  (-92.32817, 38.95273)  9622 2021/09/17          9       17      2021
# 9512  (-92.32817, 38.95273)  9623 2021/09/17          9       17      2021
# 9513  (-92.32817, 38.95273)  9624 2021/09/16          9       16      2021
# 9514  (-92.32817, 38.95273)  9625 2021/09/16          9       16      2021
# 9515  (-92.32817, 38.95273)  9626 2021/09/14          9       14      2021
# 9516  (-92.32817, 38.95273)  9627 2021/09/14          9       14      2021
# 9517  (-92.32817, 38.95273)  9628 2021/09/14          9       14      2021
# 9518  (-92.32817, 38.95273)  9629 2021/09/13          9       13      2021
# 9519  (-92.32817, 38.95273)  9630 2021/09/13          9       13      2021
# 9520  (-92.32817, 38.95273)  9631 2021/09/13          9       13      2021
# 9521  (-92.32817, 38.95273)  9632 2021/09/13          9       13      2021
# 9522  (-92.32817, 38.95273)  9633 2021/09/12          9       12      2021
# 9523  (-92.32817, 38.95273)  9634 2021/09/11          9       11      2021
# 9524  (-92.32817, 38.95273)  9635 2021/09/11          9       11      2021
# 9525  (-92.32817, 38.95273)  9636 2021/09/11          9       11      2021
# 9526  (-92.32817, 38.95273)  9637 2021/09/11          9       11      2021
# 9527  (-92.32817, 38.95273)  9638 2021/09/11          9       11      2021
# 9528  (-92.32817, 38.95273)  9639 2021/09/11          9       11      2021
# 9529  (-92.32817, 38.95273)  9640 2021/09/11          9       11      2021
# 9530  (-92.32817, 38.95273)  9641 2021/09/11          9       11      2021
# 9531  (-92.32817, 38.95273)  9642 2021/09/11          9       11      2021
# 9532  (-92.32817, 38.95273)  9643 2021/09/11          9       11      2021
# 9533  (-92.32817, 38.95273)  9644 2021/09/10          9       10      2021
# 9534  (-92.32817, 38.95273)  9645 2021/09/10          9       10      2021
# 9535  (-92.32817, 38.95273)  9646 2021/09/10          9       10      2021
# 9536  (-92.32817, 38.95273)  9647 2021/09/09          9        9      2021
# 9537  (-92.32817, 38.95273)  9648 2021/09/07          9        7      2021
# 9538  (-92.32817, 38.95273)  9649 2021/09/07          9        7      2021
# 9539  (-92.32817, 38.95273)  9650 2021/09/06          9        6      2021
# 9540  (-92.32817, 38.95273)  9651 2021/09/04          9        4      2021
# 9541  (-92.32817, 38.95273)  9652 2021/09/03          9        3      2021
# 9542  (-92.32817, 38.95273)  9653 2021/09/03          9        3      2021
# 9543  (-92.32817, 38.95273)  9654 2021/09/03          9        3      2021
# 9544  (-92.32817, 38.95273)  9655 2021/09/02          9        2      2021
# 9545  (-92.32817, 38.95273)  9656 2021/09/02          9        2      2021
# 9546  (-92.32817, 38.95273)  9657 2021/09/01          9        1      2021
# 11051 (-92.33217, 38.94079) 11162 2021/09/27          9       27      2021
# 11052 (-92.33217, 38.94079) 11163 2021/09/26          9       26      2021
# 11053 (-92.33217, 38.94079) 11164 2021/09/26          9       26      2021
# 11054 (-92.33217, 38.94079) 11165 2021/09/26          9       26      2021
# 11055 (-92.33217, 38.94079) 11166 2021/09/26          9       26      2021
# 11056 (-92.33217, 38.94079) 11167 2021/09/26          9       26      2021
# 11057 (-92.33217, 38.94079) 11168 2021/09/26          9       26      2021
# 11058 (-92.33217, 38.94079) 11169 2021/09/26          9       26      2021
# 11059 (-92.33217, 38.94079) 11170 2021/09/25          9       25      2021
# 11060 (-92.33217, 38.94079) 11171 2021/09/25          9       25      2021
# 11061 (-92.33217, 38.94079) 11172 2021/09/25          9       25      2021
# 11062 (-92.33217, 38.94079) 11173 2021/09/25          9       25      2021
# 11063 (-92.33217, 38.94079) 11174 2021/09/25          9       25      2021
# 11064 (-92.33217, 38.94079) 11175 2021/09/25          9       25      2021
# 11065 (-92.33217, 38.94079) 11176 2021/09/25          9       25      2021
# 11066 (-92.33217, 38.94079) 11177 2021/09/25          9       25      2021
# 11067 (-92.33217, 38.94079) 11178 2021/09/25          9       25      2021
# 11068 (-92.33217, 38.94079) 11179 2021/09/25          9       25      2021
# 11069 (-92.33217, 38.94079) 11180 2021/09/25          9       25      2021
# 11070 (-92.33217, 38.94079) 11181 2021/09/25          9       25      2021
# 11071 (-92.33217, 38.94079) 11182 2021/09/25          9       25      2021
# 11072 (-92.33217, 38.94079) 11183 2021/09/25          9       25      2021
# 11073 (-92.33217, 38.94079) 11184 2021/09/25          9       25      2021
# 11074 (-92.33217, 38.94079) 11185 2021/09/25          9       25      2021
# 11075 (-92.33217, 38.94079) 11186 2021/09/25          9       25      2021
# 11076 (-92.33217, 38.94079) 11187 2021/09/24          9       24      2021
# 11077 (-92.33217, 38.94079) 11188 2021/09/23          9       23      2021
# 11078 (-92.33217, 38.94079) 11189 2021/09/21          9       21      2021
# 11079 (-92.33217, 38.94079) 11190 2021/09/21          9       21      2021
# 11080 (-92.33217, 38.94079) 11191 2021/09/19          9       19      2021
# 11081 (-92.33217, 38.94079) 11192 2021/09/18          9       18      2021
# 11082 (-92.33217, 38.94079) 11193 2021/09/18          9       18      2021
# 11083 (-92.33217, 38.94079) 11194 2021/09/04          9        4      2021
# 11084 (-92.33217, 38.94079) 11195 2021/09/02          9        2      2021
# 12733 (-92.32777, 38.95094) 12844 2021/09/28          9       28      2021
# 12734 (-92.32777, 38.95094) 12845 2021/09/27          9       27      2021
# 12735 (-92.32777, 38.95094) 12846 2021/09/22          9       22      2021
# 12736 (-92.32777, 38.95094) 12847 2021/09/15          9       15      2021
# 12737 (-92.32777, 38.95094) 12848 2021/09/14          9       14      2021
# 12738 (-92.32777, 38.95094) 12849 2021/09/02          9        2      2021
# 12739 (-92.32777, 38.95094) 12850 2021/09/02          9        2      2021
# 13908 (-92.32817, 38.94571) 14019 2021/09/24          9       24      2021
# 14069 (-92.33114, 38.95128) 14180 2021/09/08          9        8      2021
# 14070 (-92.33114, 38.95128) 14181 2021/09/07          9        7      2021
# 14071 (-92.33114, 38.95128) 14182 2021/09/06          9        6      2021
# 14072 (-92.33114, 38.95128) 14183 2021/09/06          9        6      2021
# 14073 (-92.33114, 38.95128) 14184 2021/09/06          9        6      2021
# 14074 (-92.33114, 38.95128) 14185 2021/09/06          9        6      2021
# 14075 (-92.33114, 38.95128) 14186 2021/09/06          9        6      2021
# 14076 (-92.33114, 38.95128) 14187 2021/09/06          9        6      2021
# 14077 (-92.33114, 38.95128) 14188 2021/09/06          9        6      2021
# 14078 (-92.33114, 38.95128) 14189 2021/09/05          9        5      2021
# 14079 (-92.33114, 38.95128) 14190 2021/09/05          9        5      2021
# 14080 (-92.33114, 38.95128) 14191 2021/09/05          9        5      2021
# 14081 (-92.33114, 38.95128) 14192 2021/09/05          9        5      2021
# 14082 (-92.33114, 38.95128) 14193 2021/09/05          9        5      2021
# 14083 (-92.33114, 38.95128) 14194 2021/09/05          9        5      2021
# 14130 (-92.33279, 38.95122) 14241 2021/09/30          9       30      2021
# 14131 (-92.33279, 38.95122) 14242 2021/09/30          9       30      2021
# 14132 (-92.33279, 38.95122) 14243 2021/09/29          9       29      2021
# 14133 (-92.33279, 38.95122) 14244 2021/09/26          9       26      2021
# 14134 (-92.33279, 38.95122) 14245 2021/09/26          9       26      2021
# 14135 (-92.33279, 38.95122) 14246 2021/09/25          9       25      2021
# 14136 (-92.33279, 38.95122) 14247 2021/09/23          9       23      2021
# 14137 (-92.33279, 38.95122) 14248 2021/09/22          9       22      2021
# 14138 (-92.33279, 38.95122) 14249 2021/09/21          9       21      2021
# 14139 (-92.33279, 38.95122) 14250 2021/09/20          9       20      2021
# 14140 (-92.33279, 38.95122) 14251 2021/09/19          9       19      2021
# 14141 (-92.33279, 38.95122) 14252 2021/09/19          9       19      2021
# 14142 (-92.33279, 38.95122) 14253 2021/09/19          9       19      2021
# 14143 (-92.33279, 38.95122) 14254 2021/09/15          9       15      2021
# 14144 (-92.33279, 38.95122) 14255 2021/09/04          9        4      2021
# 14145 (-92.33279, 38.95122) 14256 2021/09/04          9        4      2021
# 14146 (-92.33279, 38.95122) 14257 2021/09/03          9        3      2021
# 14147 (-92.33279, 38.95122) 14258 2021/09/01          9        1      2021
# 15943 (-92.32777, 38.95088) 16054 2021/09/09          9        9      2021
# 16287  (-92.3278, 38.95139) 16398 2021/09/30          9       30      2021
# 16288  (-92.3278, 38.95139) 16399 2021/09/30          9       30      2021
# 16289  (-92.3278, 38.95139) 16400 2021/09/30          9       30      2021
# 16290  (-92.3278, 38.95139) 16401 2021/09/29          9       29      2021
# 16291  (-92.3278, 38.95139) 16402 2021/09/28          9       28      2021
# 16292  (-92.3278, 38.95139) 16403 2021/09/27          9       27      2021
# 16293  (-92.3278, 38.95139) 16404 2021/09/24          9       24      2021
# 16294  (-92.3278, 38.95139) 16405 2021/09/24          9       24      2021
# 16295  (-92.3278, 38.95139) 16406 2021/09/24          9       24      2021
# 16296  (-92.3278, 38.95139) 16407 2021/09/24          9       24      2021
# 16297  (-92.3278, 38.95139) 16408 2021/09/23          9       23      2021
# 16298  (-92.3278, 38.95139) 16409 2021/09/23          9       23      2021
# 16299  (-92.3278, 38.95139) 16410 2021/09/23          9       23      2021
# 16300  (-92.3278, 38.95139) 16411 2021/09/21          9       21      2021
# 16301  (-92.3278, 38.95139) 16412 2021/09/21          9       21      2021
# 16302  (-92.3278, 38.95139) 16413 2021/09/20          9       20      2021
# 16303  (-92.3278, 38.95139) 16414 2021/09/18          9       18      2021
# 16304  (-92.3278, 38.95139) 16415 2021/09/17          9       17      2021
# 16305  (-92.3278, 38.95139) 16416 2021/09/17          9       17      2021
# 16306  (-92.3278, 38.95139) 16417 2021/09/17          9       17      2021
# 16307  (-92.3278, 38.95139) 16418 2021/09/17          9       17      2021
# 16308  (-92.3278, 38.95139) 16419 2021/09/16          9       16      2021
# 16309  (-92.3278, 38.95139) 16420 2021/09/16          9       16      2021
# 16310  (-92.3278, 38.95139) 16421 2021/09/16          9       16      2021
# 16311  (-92.3278, 38.95139) 16422 2021/09/16          9       16      2021
# 16312  (-92.3278, 38.95139) 16423 2021/09/15          9       15      2021
# 16313  (-92.3278, 38.95139) 16424 2021/09/15          9       15      2021
# 16314  (-92.3278, 38.95139) 16425 2021/09/14          9       14      2021
# 16315  (-92.3278, 38.95139) 16426 2021/09/14          9       14      2021
# 16316  (-92.3278, 38.95139) 16427 2021/09/14          9       14      2021
# 16317  (-92.3278, 38.95139) 16428 2021/09/13          9       13      2021
# 16318  (-92.3278, 38.95139) 16429 2021/09/13          9       13      2021
# 16319  (-92.3278, 38.95139) 16430 2021/09/10          9       10      2021
# 16320  (-92.3278, 38.95139) 16431 2021/09/10          9       10      2021
# 16321  (-92.3278, 38.95139) 16432 2021/09/09          9        9      2021
# 16322  (-92.3278, 38.95139) 16433 2021/09/09          9        9      2021
# 16323  (-92.3278, 38.95139) 16434 2021/09/09          9        9      2021
# 16324  (-92.3278, 38.95139) 16435 2021/09/09          9        9      2021
# 16325  (-92.3278, 38.95139) 16436 2021/09/08          9        8      2021
# 16326  (-92.3278, 38.95139) 16437 2021/09/07          9        7      2021
# 16327  (-92.3278, 38.95139) 16438 2021/09/07          9        7      2021
# 16328  (-92.3278, 38.95139) 16439 2021/09/06          9        6      2021
# 16329  (-92.3278, 38.95139) 16440 2021/09/04          9        4      2021
# 16330  (-92.3278, 38.95139) 16441 2021/09/04          9        4      2021
# 16331  (-92.3278, 38.95139) 16442 2021/09/04          9        4      2021
# 16332  (-92.3278, 38.95139) 16443 2021/09/02          9        2      2021
# 16333  (-92.3278, 38.95139) 16444 2021/09/02          9        2      2021
# 16334  (-92.3278, 38.95139) 16445 2021/09/01          9        1      2021
# 18058   (-92.3288, 38.9453) 18169 2021/09/27          9       27      2021
# 18059   (-92.3288, 38.9453) 18170 2021/09/26          9       26      2021
# 18060   (-92.3288, 38.9453) 18171 2021/09/20          9       20      2021
# 18061   (-92.3288, 38.9453) 18172 2021/09/19          9       19      2021
# 18062   (-92.3288, 38.9453) 18173 2021/09/16          9       16      2021
# 18063   (-92.3288, 38.9453) 18174 2021/09/11          9       11      2021
# 18064   (-92.3288, 38.9453) 18175 2021/09/05          9        5      2021
# 18065   (-92.3288, 38.9453) 18176 2021/09/01          9        1      2021
# 18223 (-92.32821, 38.95427) 18334 2021/09/30          9       30      2021
# 18224 (-92.32821, 38.95427) 18335 2021/09/28          9       28      2021
# 18225 (-92.32821, 38.95427) 18336 2021/09/05          9        5      2021
# 18436  (-92.33097, 38.9411) 18547 2021/09/26          9       26      2021
# 18437  (-92.33097, 38.9411) 18548 2021/09/26          9       26      2021
# 18438  (-92.33097, 38.9411) 18549 2021/09/25          9       25      2021
# 18439  (-92.33097, 38.9411) 18550 2021/09/24          9       24      2021
# 18440  (-92.33097, 38.9411) 18551 2021/09/21          9       21      2021
# 18441  (-92.33097, 38.9411) 18552 2021/09/20          9       20      2021
# 18442  (-92.33097, 38.9411) 18553 2021/09/20          9       20      2021
# 18443  (-92.33097, 38.9411) 18554 2021/09/19          9       19      2021
# 18444  (-92.33097, 38.9411) 18555 2021/09/19          9       19      2021
# 18445  (-92.33097, 38.9411) 18556 2021/09/18          9       18      2021
# 18446  (-92.33097, 38.9411) 18557 2021/09/18          9       18      2021
# 18447  (-92.33097, 38.9411) 18558 2021/09/17          9       17      2021
# 18448  (-92.33097, 38.9411) 18559 2021/09/17          9       17      2021
# 18449  (-92.33097, 38.9411) 18560 2021/09/17          9       17      2021
# 18450  (-92.33097, 38.9411) 18561 2021/09/17          9       17      2021
# 18451  (-92.33097, 38.9411) 18562 2021/09/17          9       17      2021
# 18452  (-92.33097, 38.9411) 18563 2021/09/17          9       17      2021
# 18453  (-92.33097, 38.9411) 18564 2021/09/17          9       17      2021
# 18454  (-92.33097, 38.9411) 18565 2021/09/17          9       17      2021
# 18455  (-92.33097, 38.9411) 18566 2021/09/17          9       17      2021
# 18456  (-92.33097, 38.9411) 18567 2021/09/17          9       17      2021
# 18457  (-92.33097, 38.9411) 18568 2021/09/16          9       16      2021
# 18458  (-92.33097, 38.9411) 18569 2021/09/16          9       16      2021
# 18459  (-92.33097, 38.9411) 18570 2021/09/16          9       16      2021
# 18460  (-92.33097, 38.9411) 18571 2021/09/13          9       13      2021
# 18461  (-92.33097, 38.9411) 18572 2021/09/13          9       13      2021
# 18462  (-92.33097, 38.9411) 18573 2021/09/13          9       13      2021
# 18463  (-92.33097, 38.9411) 18574 2021/09/12          9       12      2021
# 18464  (-92.33097, 38.9411) 18575 2021/09/07          9        7      2021
# 18465  (-92.33097, 38.9411) 18576 2021/09/01          9        1      2021
# 20402 (-92.32603, 38.95219) 20513 2021/09/28          9       28      2021
# 20403 (-92.32603, 38.95219) 20514 2021/09/27          9       27      2021
# 20404 (-92.32603, 38.95219) 20515 2021/09/26          9       26      2021
# 20405 (-92.32603, 38.95219) 20516 2021/09/26          9       26      2021
# 20406 (-92.32603, 38.95219) 20517 2021/09/24          9       24      2021
# 20407 (-92.32603, 38.95219) 20518 2021/09/21          9       21      2021
# 20408 (-92.32603, 38.95219) 20519 2021/09/20          9       20      2021
# 20409 (-92.32603, 38.95219) 20520 2021/09/06          9        6      2021
# 20410 (-92.32603, 38.95219) 20521 2021/09/06          9        6      2021
# 20411 (-92.32603, 38.95219) 20522 2021/09/06          9        6      2021
# 20412 (-92.32603, 38.95219) 20523 2021/09/06          9        6      2021
# 20413 (-92.32603, 38.95219) 20524 2021/09/06          9        6      2021
# 20414 (-92.32603, 38.95219) 20525 2021/09/05          9        5      2021
# 20415 (-92.32603, 38.95219) 20526 2021/09/05          9        5      2021
# 20416 (-92.32603, 38.95219) 20527 2021/09/03          9        3      2021
# 20417 (-92.32603, 38.95219) 20528 2021/09/03          9        3      2021
# 20418 (-92.32603, 38.95219) 20529 2021/09/03          9        3      2021
# 20592 (-92.32882, 38.94536) 20703 2021/09/28          9       28      2021
# 20593 (-92.32882, 38.94536) 20704 2021/09/23          9       23      2021
# 20594 (-92.32882, 38.94536) 20705 2021/09/10          9       10      2021
# 20595 (-92.32882, 38.94536) 20706 2021/09/07          9        7      2021
# 22566 (-92.32667, 38.94278) 22677 2021/09/29          9       29      2021
# 22567 (-92.32667, 38.94278) 22678 2021/09/28          9       28      2021
# 22568 (-92.32667, 38.94278) 22679 2021/09/27          9       27      2021
# 22569 (-92.32667, 38.94278) 22680 2021/09/27          9       27      2021
# 22570 (-92.32667, 38.94278) 22681 2021/09/27          9       27      2021
# 22571 (-92.32667, 38.94278) 22682 2021/09/27          9       27      2021
# 22572 (-92.32667, 38.94278) 22683 2021/09/26          9       26      2021
# 22573 (-92.32667, 38.94278) 22684 2021/09/24          9       24      2021
# 22574 (-92.32667, 38.94278) 22685 2021/09/22          9       22      2021
# 22575 (-92.32667, 38.94278) 22686 2021/09/21          9       21      2021
# 22576 (-92.32667, 38.94278) 22687 2021/09/21          9       21      2021
# 22577 (-92.32667, 38.94278) 22688 2021/09/20          9       20      2021
# 22578 (-92.32667, 38.94278) 22689 2021/09/20          9       20      2021
# 22579 (-92.32667, 38.94278) 22690 2021/09/16          9       16      2021
# 22580 (-92.32667, 38.94278) 22691 2021/09/16          9       16      2021
# 22581 (-92.32667, 38.94278) 22692 2021/09/15          9       15      2021
# 22582 (-92.32667, 38.94278) 22693 2021/09/15          9       15      2021
# 22583 (-92.32667, 38.94278) 22694 2021/09/14          9       14      2021
# 22584 (-92.32667, 38.94278) 22695 2021/09/14          9       14      2021
# 22585 (-92.32667, 38.94278) 22696 2021/09/14          9       14      2021
# 22586 (-92.32667, 38.94278) 22697 2021/09/14          9       14      2021
# 22587 (-92.32667, 38.94278) 22698 2021/09/14          9       14      2021
# 22588 (-92.32667, 38.94278) 22699 2021/09/13          9       13      2021
# 22589 (-92.32667, 38.94278) 22700 2021/09/13          9       13      2021
# 22590 (-92.32667, 38.94278) 22701 2021/09/10          9       10      2021
# 22591 (-92.32667, 38.94278) 22702 2021/09/09          9        9      2021
# 22592 (-92.32667, 38.94278) 22703 2021/09/09          9        9      2021
# 22593 (-92.32667, 38.94278) 22704 2021/09/08          9        8      2021
# 22594 (-92.32667, 38.94278) 22705 2021/09/08          9        8      2021
# 22595 (-92.32667, 38.94278) 22706 2021/09/07          9        7      2021
# 22596 (-92.32667, 38.94278) 22707 2021/09/06          9        6      2021
# 22597 (-92.32667, 38.94278) 22708 2021/09/03          9        3      2021
# 22598 (-92.32667, 38.94278) 22709 2021/09/03          9        3      2021
# 22599 (-92.32667, 38.94278) 22710 2021/09/02          9        2      2021
# 22600 (-92.32667, 38.94278) 22711 2021/09/01          9        1      2021
# 22601 (-92.32667, 38.94278) 22712 2021/09/01          9        1      2021
# 24678 (-92.32666, 38.95194) 24789 2021/09/30          9       30      2021
# 24679 (-92.32666, 38.95194) 24790 2021/09/29          9       29      2021
# 24680 (-92.32666, 38.95194) 24791 2021/09/27          9       27      2021
# 24681 (-92.32666, 38.95194) 24792 2021/09/27          9       27      2021
# 24682 (-92.32666, 38.95194) 24793 2021/09/27          9       27      2021
# 24683 (-92.32666, 38.95194) 24794 2021/09/25          9       25      2021
# 24684 (-92.32666, 38.95194) 24795 2021/09/23          9       23      2021
# 24685 (-92.32666, 38.95194) 24796 2021/09/22          9       22      2021
# 24686 (-92.32666, 38.95194) 24797 2021/09/21          9       21      2021
# 24687 (-92.32666, 38.95194) 24798 2021/09/19          9       19      2021
# 24688 (-92.32666, 38.95194) 24799 2021/09/19          9       19      2021
# 24689 (-92.32666, 38.95194) 24800 2021/09/19          9       19      2021
# 24690 (-92.32666, 38.95194) 24801 2021/09/15          9       15      2021
# 24691 (-92.32666, 38.95194) 24802 2021/09/15          9       15      2021
# 24692 (-92.32666, 38.95194) 24803 2021/09/14          9       14      2021
# 24693 (-92.32666, 38.95194) 24804 2021/09/14          9       14      2021
# 24694 (-92.32666, 38.95194) 24805 2021/09/11          9       11      2021
# 24695 (-92.32666, 38.95194) 24806 2021/09/10          9       10      2021
# 24696 (-92.32666, 38.95194) 24807 2021/09/09          9        9      2021
# 24697 (-92.32666, 38.95194) 24808 2021/09/09          9        9      2021
# 24698 (-92.32666, 38.95194) 24809 2021/09/08          9        8      2021
# 24699 (-92.32666, 38.95194) 24810 2021/09/06          9        6      2021
# 24700 (-92.32666, 38.95194) 24811 2021/09/06          9        6      2021
# 24701 (-92.32666, 38.95194) 24812 2021/09/06          9        6      2021
# 24702 (-92.32666, 38.95194) 24813 2021/09/04          9        4      2021
# 24703 (-92.32666, 38.95194) 24814 2021/09/04          9        4      2021
# 24704 (-92.32666, 38.95194) 24815 2021/09/03          9        3      2021
# 24705 (-92.32666, 38.95194) 24816 2021/09/02          9        2      2021
# 24706 (-92.32666, 38.95194) 24817 2021/09/01          9        1      2021
# 26822  (-92.32788, 38.9492) 26933 2021/09/28          9       28      2021
# 26823  (-92.32788, 38.9492) 26934 2021/09/27          9       27      2021
# 26824  (-92.32788, 38.9492) 26935 2021/09/27          9       27      2021
# 26825  (-92.32788, 38.9492) 26936 2021/09/25          9       25      2021
# 26826  (-92.32788, 38.9492) 26937 2021/09/23          9       23      2021
# 26827  (-92.32788, 38.9492) 26938 2021/09/21          9       21      2021
# 26828  (-92.32788, 38.9492) 26939 2021/09/20          9       20      2021
# 26829  (-92.32788, 38.9492) 26940 2021/09/20          9       20      2021
# 26830  (-92.32788, 38.9492) 26941 2021/09/17          9       17      2021
# 26831  (-92.32788, 38.9492) 26942 2021/09/17          9       17      2021
# 26832  (-92.32788, 38.9492) 26943 2021/09/17          9       17      2021
# 26833  (-92.32788, 38.9492) 26944 2021/09/17          9       17      2021
# 26834  (-92.32788, 38.9492) 26945 2021/09/16          9       16      2021
# 26835  (-92.32788, 38.9492) 26946 2021/09/15          9       15      2021
# 26836  (-92.32788, 38.9492) 26947 2021/09/13          9       13      2021
# 26837  (-92.32788, 38.9492) 26948 2021/09/13          9       13      2021
# 26838  (-92.32788, 38.9492) 26949 2021/09/08          9        8      2021
# 26839  (-92.32788, 38.9492) 26950 2021/09/03          9        3      2021
# 28961  (-92.32732, 38.9506) 29072 2021/09/25          9       25      2021
# 28962  (-92.32732, 38.9506) 29073 2021/09/17          9       17      2021
# 28963  (-92.32732, 38.9506) 29074 2021/09/13          9       13      2021
# 29231 (-92.32726, 38.95229) 29342 2021/09/30          9       30      2021
# 29532  (-92.33069, 38.9486) 29643 2021/09/25          9       25      2021
# 29533  (-92.33069, 38.9486) 29644 2021/09/24          9       24      2021
# 29534  (-92.33069, 38.9486) 29645 2021/09/21          9       21      2021
# 29535  (-92.33069, 38.9486) 29646 2021/09/18          9       18      2021
# 29536  (-92.33069, 38.9486) 29647 2021/09/17          9       17      2021
# 29537  (-92.33069, 38.9486) 29648 2021/09/15          9       15      2021
# 29538  (-92.33069, 38.9486) 29649 2021/09/15          9       15      2021
# 29539  (-92.33069, 38.9486) 29650 2021/09/08          9        8      2021
# 29540  (-92.33069, 38.9486) 29651 2021/09/08          9        8      2021
# 29541  (-92.33069, 38.9486) 29652 2021/09/03          9        3      2021
# 29801  (-92.3278, 38.95055) 29915 2021/09/17          9       17      2021
# 29802  (-92.3278, 38.95055) 29916 2021/09/09          9        9      2021
# 29803  (-92.3278, 38.95055) 29917 2021/09/02          9        2      2021
# 30124 (-92.32789, 38.94908) 30238 2021/09/28          9       28      2021
# 30125 (-92.32789, 38.94908) 30239 2021/09/24          9       24      2021
# 30126 (-92.32789, 38.94908) 30240 2021/09/23          9       23      2021
# 30127 (-92.32789, 38.94908) 30241 2021/09/16          9       16      2021
# 30128 (-92.32789, 38.94908) 30242 2021/09/12          9       12      2021
# 30129 (-92.32789, 38.94908) 30243 2021/09/11          9       11      2021
# 30408 (-92.32762, 38.95264) 30522 2021/09/25          9       25      2021
# 30409 (-92.32762, 38.95264) 30523 2021/09/25          9       25      2021
# 30410 (-92.32762, 38.95264) 30524 2021/09/17          9       17      2021
# 30411 (-92.32762, 38.95264) 30525 2021/09/01          9        1      2021
# 34580 (-92.32706, 38.95121) 34694 2021/09/07          9        7      2021
# 35007 (-92.33318, 38.94344) 35121 2021/09/23          9       23      2021
# 35008 (-92.33318, 38.94344) 35122 2021/09/15          9       15      2021
# 35009 (-92.33318, 38.94344) 35123 2021/09/14          9       14      2021
# 35551 (-92.32747, 38.94838) 35665 2021/09/28          9       28      2021
# 35552 (-92.32747, 38.94838) 35666 2021/09/26          9       26      2021
# 35553 (-92.32747, 38.94838) 35667 2021/09/20          9       20      2021
# 35554 (-92.32747, 38.94838) 35668 2021/09/19          9       19      2021
# 35555 (-92.32747, 38.94838) 35669 2021/09/16          9       16      2021
# 35556 (-92.32747, 38.94838) 35670 2021/09/12          9       12      2021
# 35557 (-92.32747, 38.94838) 35671 2021/09/05          9        5      2021
# 36057 (-92.32702, 38.95149) 36171 2021/09/12          9       12      2021
# 36160 (-92.32773, 38.95234) 36274 2021/09/20          9       20      2021
# 36161 (-92.32773, 38.95234) 36275 2021/09/10          9       10      2021
# 36636 (-92.33288, 38.94928) 36750 2021/09/05          9        5      2021
# 36637 (-92.33288, 38.94928) 36751 2021/09/05          9        5      2021
# 36691 (-92.32961, 38.94282) 36805 2021/09/07          9        7      2021
# 36692 (-92.32961, 38.94282) 36806 2021/09/01          9        1      2021
# 36784 (-92.33157, 38.94169) 36898 2021/09/26          9       26      2021
# 36785 (-92.33157, 38.94169) 36899 2021/09/26          9       26      2021
# 36786 (-92.33157, 38.94169) 36900 2021/09/26          9       26      2021
# 36787 (-92.33157, 38.94169) 36901 2021/09/26          9       26      2021
# 36788 (-92.33157, 38.94169) 36902 2021/09/26          9       26      2021
# 36789 (-92.33157, 38.94169) 36903 2021/09/26          9       26      2021
# 36790 (-92.33157, 38.94169) 36904 2021/09/26          9       26      2021
# 36791 (-92.33157, 38.94169) 36905 2021/09/26          9       26      2021
# 36792 (-92.33157, 38.94169) 36906 2021/09/25          9       25      2021
# 36793 (-92.33157, 38.94169) 36907 2021/09/25          9       25      2021
# 36794 (-92.33157, 38.94169) 36908 2021/09/25          9       25      2021
# 36795 (-92.33157, 38.94169) 36909 2021/09/25          9       25      2021
# 36796 (-92.33157, 38.94169) 36910 2021/09/25          9       25      2021
# 36797 (-92.33157, 38.94169) 36911 2021/09/22          9       22      2021
# 36798 (-92.33157, 38.94169) 36912 2021/09/16          9       16      2021
# 36799 (-92.33157, 38.94169) 36913 2021/09/16          9       16      2021
# 36800 (-92.33157, 38.94169) 36914 2021/09/15          9       15      2021
# 36801 (-92.33157, 38.94169) 36915 2021/09/15          9       15      2021
# 36802 (-92.33157, 38.94169) 36916 2021/09/14          9       14      2021
# 36803 (-92.33157, 38.94169) 36917 2021/09/13          9       13      2021
# 36804 (-92.33157, 38.94169) 36918 2021/09/10          9       10      2021
# 37479  (-92.3274, 38.95086) 37593 2021/09/30          9       30      2021
# 37480  (-92.3274, 38.95086) 37594 2021/09/29          9       29      2021
# 37481  (-92.3274, 38.95086) 37595 2021/09/28          9       28      2021
# 37482  (-92.3274, 38.95086) 37596 2021/09/26          9       26      2021
# 37483  (-92.3274, 38.95086) 37597 2021/09/14          9       14      2021
# 37484  (-92.3274, 38.95086) 37598 2021/09/08          9        8      2021
# 37485  (-92.3274, 38.95086) 37599 2021/09/07          9        7      2021
# 37486  (-92.3274, 38.95086) 37600 2021/09/06          9        6      2021
# 37487  (-92.3274, 38.95086) 37601 2021/09/05          9        5      2021
# 37488  (-92.3274, 38.95086) 37602 2021/09/02          9        2      2021
# 37489  (-92.3274, 38.95086) 37603 2021/09/02          9        2      2021
# 37490  (-92.3274, 38.95086) 37604 2021/09/01          9        1      2021
# 38190 (-92.32772, 38.95121) 38304 2021/09/26          9       26      2021
# 38191 (-92.32772, 38.95121) 38305 2021/09/23          9       23      2021
# 38192 (-92.32772, 38.95121) 38306 2021/09/16          9       16      2021
# 38193 (-92.32772, 38.95121) 38307 2021/09/01          9        1      2021
# 38845 (-92.33351, 38.94533) 38959 2021/09/30          9       30      2021
# 38846 (-92.33351, 38.94533) 38960 2021/09/28          9       28      2021
# 38847 (-92.33351, 38.94533) 38961 2021/09/22          9       22      2021
# 38848 (-92.33351, 38.94533) 38962 2021/09/10          9       10      2021
# 38849 (-92.33351, 38.94533) 38963 2021/09/10          9       10      2021
# 38850 (-92.33351, 38.94533) 38964 2021/09/10          9       10      2021
# 38851 (-92.33351, 38.94533) 38965 2021/09/10          9       10      2021
# 39616 (-92.32725, 38.94984) 39730 2021/09/30          9       30      2021
# 39617 (-92.32725, 38.94984) 39731 2021/09/27          9       27      2021
# 39618 (-92.32725, 38.94984) 39732 2021/09/27          9       27      2021
# 39619 (-92.32725, 38.94984) 39733 2021/09/26          9       26      2021
# 39620 (-92.32725, 38.94984) 39734 2021/09/25          9       25      2021
# 39621 (-92.32725, 38.94984) 39735 2021/09/24          9       24      2021
# 39622 (-92.32725, 38.94984) 39736 2021/09/23          9       23      2021
# 39623 (-92.32725, 38.94984) 39737 2021/09/20          9       20      2021
# 39624 (-92.32725, 38.94984) 39738 2021/09/19          9       19      2021
# 39625 (-92.32725, 38.94984) 39739 2021/09/18          9       18      2021
# 39626 (-92.32725, 38.94984) 39740 2021/09/17          9       17      2021
# 39627 (-92.32725, 38.94984) 39741 2021/09/16          9       16      2021
# 39628 (-92.32725, 38.94984) 39742 2021/09/16          9       16      2021
# 39629 (-92.32725, 38.94984) 39743 2021/09/14          9       14      2021
# 39630 (-92.32725, 38.94984) 39744 2021/09/11          9       11      2021
# 39631 (-92.32725, 38.94984) 39745 2021/09/11          9       11      2021
# 39632 (-92.32725, 38.94984) 39746 2021/09/10          9       10      2021
# 39633 (-92.32725, 38.94984) 39747 2021/09/10          9       10      2021
# 39634 (-92.32725, 38.94984) 39748 2021/09/10          9       10      2021
# 39635 (-92.32725, 38.94984) 39749 2021/09/09          9        9      2021
# 39636 (-92.32725, 38.94984) 39750 2021/09/09          9        9      2021
# 39637 (-92.32725, 38.94984) 39751 2021/09/09          9        9      2021
# 39638 (-92.32725, 38.94984) 39752 2021/09/09          9        9      2021
# 39639 (-92.32725, 38.94984) 39753 2021/09/09          9        9      2021
# 39640 (-92.32725, 38.94984) 39754 2021/09/09          9        9      2021
# 39641 (-92.32725, 38.94984) 39755 2021/09/04          9        4      2021
# 40259 (-92.32723, 38.95077) 40373 2021/09/29          9       29      2021
# 40260 (-92.32723, 38.95077) 40374 2021/09/10          9       10      2021
# 40261 (-92.32723, 38.95077) 40375 2021/09/07          9        7      2021
# 40919 (-92.33266, 38.95124) 41033 2021/09/30          9       30      2021
# 40920 (-92.33266, 38.95124) 41034 2021/09/29          9       29      2021
# 40921 (-92.33266, 38.95124) 41035 2021/09/23          9       23      2021
# 40922 (-92.33266, 38.95124) 41036 2021/09/22          9       22      2021
# 40923 (-92.33266, 38.95124) 41037 2021/09/18          9       18      2021
# 40924 (-92.33266, 38.95124) 41038 2021/09/17          9       17      2021
# 40925 (-92.33266, 38.95124) 41039 2021/09/15          9       15      2021
# 40926 (-92.33266, 38.95124) 41040 2021/09/13          9       13      2021
# 40927 (-92.33266, 38.95124) 41041 2021/09/12          9       12      2021
# 40928 (-92.33266, 38.95124) 41042 2021/09/11          9       11      2021
# 40929 (-92.33266, 38.95124) 41043 2021/09/09          9        9      2021
# 40930 (-92.33266, 38.95124) 41044 2021/09/09          9        9      2021
# 40931 (-92.33266, 38.95124) 41045 2021/09/08          9        8      2021
# 40932 (-92.33266, 38.95124) 41046 2021/09/08          9        8      2021
# 40933 (-92.33266, 38.95124) 41047 2021/09/04          9        4      2021
# 40934 (-92.33266, 38.95124) 41048 2021/09/02          9        2      2021
# 40935 (-92.33266, 38.95124) 41049 2021/09/02          9        2      2021
# 40936 (-92.33266, 38.95124) 41050 2021/09/01          9        1      2021
# 41665 (-92.32683, 38.95286) 41779 2021/09/14          9       14      2021
# 41832 (-92.33121, 38.95124) 41946 2021/09/14          9       14      2021
# 41833 (-92.33121, 38.95124) 41947 2021/09/13          9       13      2021
# 41834 (-92.33121, 38.95124) 41948 2021/09/11          9       11      2021
# 41835 (-92.33121, 38.95124) 41949 2021/09/10          9       10      2021
# 41836 (-92.33121, 38.95124) 41950 2021/09/07          9        7      2021
# 41837 (-92.33121, 38.95124) 41951 2021/09/06          9        6      2021
# 41838 (-92.33121, 38.95124) 41952 2021/09/01          9        1      2021
# 42535  (-92.32786, 38.9492) 42649 2021/09/15          9       15      2021
# 42599  (-92.3273, 38.95233) 42713 2021/09/21          9       21      2021
# 42600  (-92.3273, 38.95233) 42714 2021/09/04          9        4      2021
# 43407 (-92.32843, 38.94887) 43521 2021/09/17          9       17      2021
# 43408 (-92.32843, 38.94887) 43522 2021/09/12          9       12      2021
# 43409 (-92.32843, 38.94887) 43523 2021/09/12          9       12      2021
# 43410 (-92.32843, 38.94887) 43524 2021/09/04          9        4      2021
# 43411 (-92.32843, 38.94887) 43525 2021/09/01          9        1      2021
# 43531 (-92.32725, 38.95082) 43645 2021/09/28          9       28      2021
# 43532 (-92.32725, 38.95082) 43646 2021/09/26          9       26      2021
# 43533 (-92.32725, 38.95082) 43647 2021/09/25          9       25      2021
# 43534 (-92.32725, 38.95082) 43648 2021/09/25          9       25      2021
# 43535 (-92.32725, 38.95082) 43649 2021/09/21          9       21      2021
# 43536 (-92.32725, 38.95082) 43650 2021/09/21          9       21      2021
# 43537 (-92.32725, 38.95082) 43651 2021/09/20          9       20      2021
# 43538 (-92.32725, 38.95082) 43652 2021/09/18          9       18      2021
# 43539 (-92.32725, 38.95082) 43653 2021/09/16          9       16      2021
# 43540 (-92.32725, 38.95082) 43654 2021/09/15          9       15      2021
# 43541 (-92.32725, 38.95082) 43655 2021/09/14          9       14      2021
# 43542 (-92.32725, 38.95082) 43656 2021/09/13          9       13      2021
# 43543 (-92.32725, 38.95082) 43657 2021/09/12          9       12      2021
# 43544 (-92.32725, 38.95082) 43658 2021/09/11          9       11      2021
# 43545 (-92.32725, 38.95082) 43659 2021/09/11          9       11      2021
# 43546 (-92.32725, 38.95082) 43660 2021/09/11          9       11      2021
# 43547 (-92.32725, 38.95082) 43661 2021/09/09          9        9      2021
# 43548 (-92.32725, 38.95082) 43662 2021/09/09          9        9      2021
# 43549 (-92.32725, 38.95082) 43663 2021/09/08          9        8      2021
# 43550 (-92.32725, 38.95082) 43664 2021/09/07          9        7      2021
# 43551 (-92.32725, 38.95082) 43665 2021/09/02          9        2      2021
# 43552 (-92.32725, 38.95082) 43666 2021/09/02          9        2      2021
# 44393 (-92.32716, 38.95113) 44507 2021/09/30          9       30      2021
# 44394 (-92.32716, 38.95113) 44508 2021/09/27          9       27      2021
# 44395 (-92.32716, 38.95113) 44509 2021/09/25          9       25      2021
# 44396 (-92.32716, 38.95113) 44510 2021/09/16          9       16      2021
# 44397 (-92.32716, 38.95113) 44511 2021/09/14          9       14      2021
# 45059  (-92.33436, 38.9423) 45173 2021/09/12          9       12      2021
# 45135 (-92.33279, 38.94458) 45249 2021/09/28          9       28      2021
# 45136 (-92.33279, 38.94458) 45250 2021/09/23          9       23      2021
# 45137 (-92.33279, 38.94458) 45251 2021/09/22          9       22      2021
# 45138 (-92.33279, 38.94458) 45252 2021/09/13          9       13      2021
# 45139 (-92.33279, 38.94458) 45253 2021/09/07          9        7      2021
# 45140 (-92.33279, 38.94458) 45254 2021/09/06          9        6      2021
# 45141 (-92.33279, 38.94458) 45255 2021/09/01          9        1      2021
# 46092 (-92.32893, 38.94409) 46206 2021/09/29          9       29      2021
# 46093 (-92.32893, 38.94409) 46207 2021/09/28          9       28      2021
# 46094 (-92.32893, 38.94409) 46208 2021/09/26          9       26      2021
# 46095 (-92.32893, 38.94409) 46209 2021/09/24          9       24      2021
# 46209 (-92.32662, 38.95168) 46323 2021/09/30          9       30      2021
# 46210 (-92.32662, 38.95168) 46324 2021/09/30          9       30      2021
# 46211 (-92.32662, 38.95168) 46325 2021/09/30          9       30      2021
# 46212 (-92.32662, 38.95168) 46326 2021/09/30          9       30      2021
# 46213 (-92.32662, 38.95168) 46327 2021/09/30          9       30      2021
# 46214 (-92.32662, 38.95168) 46328 2021/09/30          9       30      2021
# 46215 (-92.32662, 38.95168) 46329 2021/09/30          9       30      2021
# 46216 (-92.32662, 38.95168) 46330 2021/09/25          9       25      2021
# 46217 (-92.32662, 38.95168) 46331 2021/09/25          9       25      2021
# 46218 (-92.32662, 38.95168) 46332 2021/09/24          9       24      2021
# 46219 (-92.32662, 38.95168) 46333 2021/09/24          9       24      2021
# 46220 (-92.32662, 38.95168) 46334 2021/09/24          9       24      2021
# 46221 (-92.32662, 38.95168) 46335 2021/09/24          9       24      2021
# 46222 (-92.32662, 38.95168) 46336 2021/09/21          9       21      2021
# 46223 (-92.32662, 38.95168) 46337 2021/09/20          9       20      2021
# 46224 (-92.32662, 38.95168) 46338 2021/09/19          9       19      2021
# 46225 (-92.32662, 38.95168) 46339 2021/09/18          9       18      2021
# 46226 (-92.32662, 38.95168) 46340 2021/09/18          9       18      2021
# ...
# 24683 0.007164859 0.16666667 0.790909091 0.32075472 0.1851852
# 24684 0.007164859 0.16666667 0.790909091 0.32075472 0.1851852
# 24685 0.007164859 0.16666667 0.004521251 0.32075472 0.1851852
# 24686 0.007164859 0.16666667 0.004521251 0.32075472 0.1851852
# 24687 0.007164859 0.16666667 0.004521251 0.32075472 0.1851852
# 24688 0.007164859 0.16666667 0.790909091 0.32075472 0.1851852
# 24689 0.007164859 0.16666667 0.004521251 0.32075472 0.1851852
# 24690 0.007164859 0.16666667 0.790909091 0.32075472 0.1851852
# 24691 0.007164859 0.16666667 0.790909091 0.32075472 0.1851852
# 24692 0.007164859 0.16666667 0.790909091 0.32075472 0.1851852
# 24693 0.007164859 0.16666667 0.790909091 0.32075472 0.1851852
# 24694 0.007164859 0.16666667 0.790909091 0.32075472 0.1851852
# 24695 0.007164859 0.16666667 0.004521251 0.32075472 0.1851852
# 24696 0.007164859 0.16666667 0.790909091 0.32075472 0.1851852
# 24697 0.007164859 0.16666667 0.004521251 0.32075472 0.1851852
# 24698 0.007164859 0.16666667 0.790909091 0.32075472 0.1851852
# 24699 0.007164859 0.16666667 0.790909091 0.32075472 0.1851852
# 24700 0.007164859 0.16666667 0.004521251 0.32075472 0.1851852
# 24701 0.007164859 0.16666667 0.790909091 0.32075472 0.1851852
# 24702 0.007164859 0.16666667 0.790909091 0.32075472 0.1851852
# 24703 0.007164859 0.16666667 0.004521251 0.32075472 0.1851852
# 24704 0.007164859 0.16666667 0.790909091 0.32075472 0.1851852
# 24705 0.007164859 0.16666667 0.790909091 0.32075472 0.1851852
# 24706 0.007164859 0.16666667 0.004521251 0.32075472 0.1851852
# 26822 0.022283954 0.14814815 0.181818182 0.41273585 0.3333333
# 26823 0.022283954 0.14814815 0.181818182 0.41273585 0.3333333
# 26824 0.022283954 0.36564534 0.181818182 0.41273585 0.3333333
# 26825 0.022283954 0.14814815 0.181818182 0.41273585 0.3333333
# 26826 0.022283954 0.36564534 0.181818182 0.41273585 0.3333333
# 26827 0.022283954 0.36564534 0.181818182 0.41273585 0.3333333
# 26828 0.022283954 0.36564534 0.181818182 0.41273585 0.3333333
# 26829 0.022283954 0.14814815 0.181818182 0.41273585 0.3333333
# 26830 0.022283954 0.14814815 0.181818182 0.41273585 0.3333333
# 26831 0.022283954 0.14814815 0.181818182 0.41273585 0.3333333
# 26832 0.022283954 0.14814815 0.181818182 0.41273585 0.3333333
# 26833 0.022283954 0.36564534 0.181818182 0.41273585 0.3333333
# 26834 0.022283954 0.36564534 0.181818182 0.41273585 0.3333333
# 26835 0.022283954 0.14814815 0.181818182 0.41273585 0.3333333
# 26836 0.022283954 0.14814815 0.181818182 0.41273585 0.3333333
# 26837 0.022283954 0.14814815 0.181818182 0.41273585 0.3333333
# 26838 0.022283954 0.36564534 0.181818182 0.41273585 0.3333333
# 26839 0.022283954 0.36564534 0.181818182 0.41273585 0.3333333
# 28961 0.064346009 0.48148148 0.790909091 0.34905660 0.1111111
# 28962 0.064346009 0.08148148 0.004521251 0.34905660 0.1111111
# 28963 0.064346009 0.48148148 0.790909091 0.34905660 0.1111111
# 29231 0.043234364 1.00000000 0.056441655 0.68413564 0.0000000
# 29532 0.010104030 0.41666667 0.000000000 0.19339623 0.5555556
# 29533 0.010104030 0.41666667 0.000000000 0.19339623 0.5555556
# 29534 0.010104030 0.41666667 0.000000000 0.19339623 0.5555556
# 29535 0.010104030 0.41666667 0.000000000 0.19339623 0.5555556
# 29536 0.010104030 0.41666667 0.000000000 0.19339623 0.5555556
# 29537 0.010104030 0.41666667 0.000000000 0.19339623 0.5555556
# 29538 0.010104030 0.41666667 0.000000000 0.19339623 0.5555556
# 29539 0.010104030 0.41666667 0.000000000 0.19339623 0.5555556
# 29540 0.010104030 0.41666667 0.000000000 0.19339623 0.5555556
# 29541 0.010104030 0.41666667 0.000000000 0.19339623 0.5555556
# 29801 0.001179027 0.38888889 0.090909091 0.20047170 0.0000000
# 29802 0.001179027 0.38888889 0.090909091 0.20047170 0.0000000
# 29803 0.001179027 0.38888889 0.090909091 0.20047170 0.0000000
# 30124 0.022283954 0.14814815 0.181818182 0.41273585 0.3333333
# 30125 0.022283954 0.36564534 0.181818182 0.41273585 0.3333333
# 30126 0.022283954 0.14814815 0.181818182 0.41273585 0.3333333
# 30127 0.022283954 0.36564534 0.181818182 0.41273585 0.3333333
# 30128 0.022283954 0.14814815 0.181818182 0.41273585 0.3333333
# 30129 0.022283954 0.36564534 0.181818182 0.41273585 0.3333333
# 30408 0.014511107 0.82642123 0.000000000 0.29952830 0.2962963
# 30409 0.014511107 0.82642123 0.000000000 0.29952830 0.2962963
# 30410 0.014511107 0.82642123 0.000000000 0.29952830 0.2962963
# 30411 0.014511107 0.11111111 0.000000000 0.29952830 0.2962963
# 34580 0.004262638 0.33333333 0.000000000 0.22169811 0.1111111
# 35007 0.018263168 0.29629630 0.090909091 0.22169811 0.2222222
# 35008 0.018263168 0.29629630 0.090909091 0.22169811 0.2222222
# 35009 0.018263168 0.29629630 0.090909091 0.22169811 0.2222222
# 35551 0.023342056 0.33333333 0.000000000 0.41981132 0.0000000
# 35552 0.023342056 0.33333333 0.000000000 0.41981132 0.0000000
# 35553 0.023342056 0.33333333 0.000000000 0.41981132 0.0000000
# 35554 0.023342056 0.33333333 0.000000000 0.41981132 0.0000000
# 35555 0.023342056 0.33333333 0.000000000 0.41981132 0.0000000
# 35556 0.023342056 0.33333333 0.000000000 0.41981132 0.0000000
# 35557 0.023342056 0.33333333 0.000000000 0.41981132 0.0000000
# 36057 0.007164859 0.16666667 0.790909091 0.32075472 0.1851852
# 36160 0.043234364 1.00000000 0.056441655 0.68413564 0.0000000
# 36161 0.043234364 1.00000000 0.056441655 0.68413564 0.0000000
# 36636 0.089461645 0.40740741 0.181818182 0.16509434 0.2222222
# 36637 0.089461645 0.40740741 0.181818182 0.16509434 0.2222222
# 36691 0.005891778 0.22222222 0.000000000 0.24292453 0.2222222
# 36692 0.005891778 0.22222222 0.000000000 0.24292453 0.2222222
# 36784 0.012754322 0.82642123 0.000000000 0.33490566 0.0000000
# 36785 0.012754322 0.82642123 0.000000000 0.33490566 0.0000000
# 36786 0.012754322 0.11111111 0.000000000 0.73564215 0.0000000
# 36787 0.012754322 0.82642123 0.000000000 0.33490566 0.0000000
# 36788 0.012754322 0.82642123 0.000000000 0.33490566 0.0000000
# 36789 0.012754322 0.82642123 0.000000000 0.33490566 0.0000000
# 36790 0.012754322 0.82642123 0.000000000 0.33490566 0.0000000
# 36791 0.012754322 0.82642123 0.000000000 0.33490566 0.0000000
# 36792 0.012754322 0.11111111 0.000000000 0.73564215 0.0000000
# 36793 0.012754322 0.82642123 0.000000000 0.33490566 0.0000000
# 36794 0.012754322 0.82642123 0.000000000 0.33490566 0.0000000
# 36795 0.012754322 0.11111111 0.000000000 0.73564215 0.0000000
# 36796 0.012754322 0.11111111 0.000000000 0.73564215 0.0000000
# 36797 0.012754322 0.82642123 0.000000000 0.33490566 0.0000000
# 36798 0.012754322 0.82642123 0.000000000 0.33490566 0.0000000
# 36799 0.012754322 0.82642123 0.000000000 0.33490566 0.0000000
# 36800 0.012754322 0.11111111 0.000000000 0.73564215 0.0000000
# 36801 0.012754322 0.11111111 0.000000000 0.73564215 0.0000000
# 36802 0.012754322 0.82642123 0.000000000 0.33490566 0.0000000
# 36803 0.012754322 0.82642123 0.000000000 0.33490566 0.0000000
# 36804 0.012754322 0.82642123 0.000000000 0.33490566 0.0000000
# 37479 0.008044931 0.11111111 0.090909091 0.65330189 0.3333333
# 37480 0.008044931 0.11111111 0.090909091 0.65330189 0.3333333
# 37481 0.008044931 0.11111111 0.090909091 0.65330189 0.3333333
# 37482 0.008044931 0.11111111 0.090909091 0.65330189 0.3333333
# 37483 0.008044931 0.11111111 0.090909091 0.65330189 0.3333333
# 37484 0.008044931 0.11111111 0.090909091 0.65330189 0.3333333
# 37485 0.008044931 0.11111111 0.090909091 0.65330189 0.3333333
# 37486 0.008044931 0.11111111 0.090909091 0.65330189 0.3333333
# 37487 0.008044931 0.11111111 0.090909091 0.65330189 0.3333333
# 37488 0.008044931 0.11111111 0.090909091 0.65330189 0.3333333
# 37489 0.008044931 0.11111111 0.090909091 0.65330189 0.3333333
# 37490 0.008044931 0.11111111 0.090909091 0.65330189 0.3333333
# 38190 0.005038579 0.27777778 0.000000000 0.13679245 0.0000000
# 38191 0.005038579 0.27777778 0.000000000 0.13679245 0.0000000
# 38192 0.005038579 0.27777778 0.000000000 0.13679245 0.0000000
# 38193 0.005038579 0.27777778 0.000000000 0.13679245 0.0000000
# 38845 0.000000000 0.33333333 0.000000000 0.22169811 0.1111111
# 38846 0.000000000 0.33333333 0.000000000 0.22169811 0.1111111
# 38847 0.000000000 0.33333333 0.000000000 0.22169811 0.1111111
# 38848 0.000000000 0.33333333 0.000000000 0.22169811 0.1111111
# 38849 0.000000000 0.33333333 0.000000000 0.22169811 0.1111111
# 38850 0.000000000 0.33333333 0.000000000 0.22169811 0.1111111
# 38851 0.000000000 0.33333333 0.000000000 0.22169811 0.1111111
# 39616 0.034460519 0.58333333 0.181818182 0.22877359 0.1666667
# 39617 0.034460519 0.58333333 0.181818182 0.22877359 0.1666667
# 39618 0.034460519 0.58333333 0.181818182 0.22877359 0.1666667
# 39619 0.034460519 0.58333333 0.181818182 0.22877359 0.1666667
# 39620 0.034460519 0.58333333 0.181818182 0.22877359 0.1666667
# 39621 0.034460519 0.58333333 0.181818182 0.22877359 0.1666667
# 39622 0.034460519 0.58333333 0.181818182 0.22877359 0.1666667
# 39623 0.034460519 0.58333333 0.181818182 0.22877359 0.1666667
# 39624 0.034460519 0.58333333 0.181818182 0.22877359 0.1666667
# 39625 0.034460519 0.58333333 0.181818182 0.22877359 0.1666667
# 39626 0.034460519 0.58333333 0.181818182 0.22877359 0.1666667
# 39627 0.034460519 0.58333333 0.181818182 0.22877359 0.1666667
# 39628 0.034460519 0.58333333 0.181818182 0.22877359 0.1666667
# 39629 0.034460519 0.58333333 0.181818182 0.22877359 0.1666667
# 39630 0.034460519 0.58333333 0.181818182 0.22877359 0.1666667
# 39631 0.034460519 0.58333333 0.181818182 0.22877359 0.1666667
# 39632 0.034460519 0.58333333 0.181818182 0.22877359 0.1666667
# 39633 0.034460519 0.58333333 0.181818182 0.22877359 0.1666667
# 39634 0.034460519 0.58333333 0.181818182 0.22877359 0.1666667
# 39635 0.034460519 0.58333333 0.181818182 0.22877359 0.1666667
# 39636 0.034460519 0.58333333 0.181818182 0.22877359 0.1666667
# 39637 0.034460519 0.58333333 0.181818182 0.22877359 0.1666667
# 39638 0.034460519 0.58333333 0.181818182 0.22877359 0.1666667
# 39639 0.034460519 0.58333333 0.181818182 0.22877359 0.1666667
# 39640 0.034460519 0.58333333 0.181818182 0.22877359 0.1666667
# 39641 0.034460519 0.58333333 0.181818182 0.22877359 0.1666667
# 40259 0.064346009 0.48148148 0.790909091 0.34905660 0.1111111
# 40260 0.064346009 0.48148148 0.790909091 0.34905660 0.1111111
# 40261 0.064346009 0.08148148 0.004521251 0.34905660 0.1111111
# 40919 0.000839763 0.22222222 0.000000000 0.38443396 0.1666667
# 40920 0.000839763 0.22222222 0.000000000 0.38443396 0.1666667
# 40921 0.000839763 0.22222222 0.000000000 0.38443396 0.1666667
# 40922 0.000839763 0.22222222 0.000000000 0.38443396 0.1666667
# 40923 0.000839763 0.22222222 0.000000000 0.38443396 0.1666667
# 40924 0.000839763 0.22222222 0.000000000 0.38443396 0.1666667
# 40925 0.000839763 0.22222222 0.000000000 0.38443396 0.1666667
# 40926 0.000839763 0.22222222 0.000000000 0.38443396 0.1666667
# 40927 0.000839763 0.22222222 0.000000000 0.38443396 0.1666667
# 40928 0.000839763 0.22222222 0.000000000 0.38443396 0.1666667
# 40929 0.000839763 0.22222222 0.000000000 0.38443396 0.1666667
# 40930 0.000839763 0.22222222 0.000000000 0.38443396 0.1666667
# 40931 0.000839763 0.22222222 0.000000000 0.38443396 0.1666667
# 40932 0.000839763 0.22222222 0.000000000 0.38443396 0.1666667
# 40933 0.000839763 0.22222222 0.000000000 0.38443396 0.1666667
# 40934 0.000839763 0.22222222 0.000000000 0.38443396 0.1666667
# 40935 0.000839763 0.22222222 0.000000000 0.38443396 0.1666667
# 40936 0.000839763 0.22222222 0.000000000 0.38443396 0.1666667
# 41665 0.023395801 0.27777778 0.000000000 0.48113208 0.2222222
# 41832 0.000000000 0.29629630 0.000000000 0.71698113 0.1666667
# 41833 0.000000000 0.29629630 0.000000000 0.71698113 0.1666667
# 41834 0.000000000 0.29629630 0.000000000 0.71698113 0.1666667
# 41835 0.000000000 0.29629630 0.000000000 0.71698113 0.1666667
# 41836 0.000000000 0.29629630 0.000000000 0.71698113 0.1666667
# 41837 0.000000000 0.29629630 0.000000000 0.71698113 0.1666667
# 41838 0.000000000 0.29629630 0.000000000 0.71698113 0.1666667
# 42535 0.022283954 0.14814815 0.181818182 0.41273585 0.3333333
# 42599 0.043234364 1.00000000 0.363636364 0.08726415 0.0000000
# 42600 0.043234364 1.00000000 0.363636364 0.08726415 0.0000000
# 43407 0.009210522 0.33333333 0.000000000 0.16509434 0.1111111
# 43408 0.009210522 0.33333333 0.000000000 0.16509434 0.1111111
# 43409 0.009210522 0.33333333 0.000000000 0.16509434 0.1111111
# 43410 0.009210522 0.33333333 0.000000000 0.16509434 0.1111111
# 43411 0.009210522 0.33333333 0.000000000 0.16509434 0.1111111
# 43531 0.008044931 0.11111111 0.090909091 0.65330189 0.3333333
# 43532 0.008044931 0.11111111 0.090909091 0.65330189 0.3333333
# 43533 0.008044931 0.11111111 0.090909091 0.65330189 0.3333333
# 43534 0.008044931 0.11111111 0.090909091 0.65330189 0.3333333
# 43535 0.008044931 0.11111111 0.090909091 0.65330189 0.3333333
# 43536 0.008044931 0.11111111 0.090909091 0.65330189 0.3333333
# 43537 0.008044931 0.11111111 0.090909091 0.65330189 0.3333333
# 43538 0.008044931 0.11111111 0.090909091 0.65330189 0.3333333
# 43539 0.008044931 0.11111111 0.090909091 0.65330189 0.3333333
# 43540 0.008044931 0.11111111 0.090909091 0.65330189 0.3333333
# 43541 0.008044931 0.11111111 0.090909091 0.65330189 0.3333333
# 43542 0.008044931 0.11111111 0.090909091 0.65330189 0.3333333
# 43543 0.008044931 0.11111111 0.090909091 0.65330189 0.3333333
# 43544 0.008044931 0.11111111 0.090909091 0.65330189 0.3333333
# 43545 0.008044931 0.11111111 0.090909091 0.65330189 0.3333333
# 43546 0.008044931 0.11111111 0.090909091 0.65330189 0.3333333
# 43547 0.008044931 0.11111111 0.090909091 0.65330189 0.3333333
# 43548 0.008044931 0.11111111 0.090909091 0.65330189 0.3333333
# 43549 0.008044931 0.11111111 0.090909091 0.65330189 0.3333333
# 43550 0.008044931 0.11111111 0.090909091 0.65330189 0.3333333
# 43551 0.008044931 0.11111111 0.090909091 0.65330189 0.3333333
# 43552 0.008044931 0.11111111 0.090909091 0.65330189 0.3333333
# 44393 0.005038579 0.27777778 0.000000000 0.13679245 0.0000000
# 44394 0.005038579 0.27777778 0.000000000 0.13679245 0.0000000
# 44395 0.005038579 0.27777778 0.000000000 0.13679245 0.0000000
# 44396 0.005038579 0.27777778 0.000000000 0.13679245 0.0000000
# 44397 0.005038579 0.27777778 0.000000000 0.13679245 0.0000000
# 45059 0.010970665 0.11111111 0.000000000 0.15094340 0.1111111
# 45135 0.005878342 0.38888889 0.000000000 0.08726415 0.1111111
# 45136 0.005878342 0.38888889 0.000000000 0.08726415 0.1111111
# 45137 0.005878342 0.38888889 0.000000000 0.08726415 0.1111111
# 45138 0.005878342 0.38888889 0.000000000 0.08726415 0.1111111
# 45139 0.005878342 0.38888889 0.000000000 0.08726415 0.1111111
# 45140 0.005878342 0.38888889 0.000000000 0.08726415 0.1111111
# 45141 0.005878342 0.38888889 0.000000000 0.08726415 0.1111111
# 46092 0.084785844 0.22222222 0.000000000 0.44339623 0.4444444
# 46093 0.084785844 0.22222222 0.000000000 0.44339623 0.4444444
# 46094 0.084785844 0.22222222 0.000000000 0.44339623 0.4444444
# 46095 0.084785844 0.22222222 0.000000000 0.44339623 0.4444444
# 46209 0.007164859 0.16666667 0.004521251 0.32075472 0.1851852
# 46210 0.007164859 0.16666667 0.004521251 0.32075472 0.1851852
# 46211 0.007164859 0.16666667 0.004521251 0.32075472 0.1851852
# 46212 0.007164859 0.16666667 0.004521251 0.32075472 0.1851852
# 46213 0.007164859 0.16666667 0.004521251 0.32075472 0.1851852
# 46214 0.007164859 0.16666667 0.790909091 0.32075472 0.1851852
# 46215 0.007164859 0.16666667 0.790909091 0.32075472 0.1851852
# 46216 0.007164859 0.16666667 0.790909091 0.32075472 0.1851852
# 46217 0.007164859 0.16666667 0.004521251 0.32075472 0.1851852
# 46218 0.007164859 0.16666667 0.004521251 0.32075472 0.1851852
# 46219 0.007164859 0.16666667 0.004521251 0.32075472 0.1851852
# 46220 0.007164859 0.16666667 0.790909091 0.32075472 0.1851852
# 46221 0.007164859 0.16666667 0.004521251 0.32075472 0.1851852
# 46222 0.007164859 0.16666667 0.790909091 0.32075472 0.1851852
# 46223 0.007164859 0.16666667 0.004521251 0.32075472 0.1851852
# 46224 0.007164859 0.16666667 0.790909091 0.32075472 0.1851852
# 46225 0.007164859 0.16666667 0.790909091 0.32075472 0.1851852
# 46226 0.007164859 0.16666667 0.790909091 0.32075472 0.1851852
# 46227 0.007164859 0.16666667 0.790909091 0.32075472 0.1851852
# 46228 0.007164859 0.16666667 0.790909091 0.32075472 0.1851852
# 46229 0.007164859 0.16666667 0.004521251 0.32075472 0.1851852
# 46230 0.007164859 0.16666667 0.790909091 0.32075472 0.1851852
# 46231 0.007164859 0.16666667 0.790909091 0.32075472 0.1851852
# 46232 0.007164859 0.16666667 0.790909091 0.32075472 0.1851852
# 46233 0.007164859 0.16666667 0.004521251 0.32075472 0.1851852

# %%
#Plotting the subset of the feature
plot(inFeaturesSubsetA)
# Out:
# plot without title

# %% [markdown]
# ## Generate Neighborhoods for Features
#
# Generate neighborhoods for each feature according to the Queen's Criterion.  Then test the neighborhoods to see if they are valid.  Retain only the features with valid neighborhoods.

# %%
# # creating neighborhood 
# #xy <- coordinates(inFeaturesSubsetA)
# inFeaturesSubsetA.nb <- knn2nb(knearneigh(inFeaturesSubsetA))
# #inFeaturesSubsetA.nb

# ## Select features with at least one neighbor.
# inFeaturesSubset <- inFeaturesSubsetA[card(inFeaturesSubsetA.nb) >= 1, ]

# ## Identify the neighbors of each feature having at least one neighbor.
# inFeaturesSubset.nb <- knn2nb(knearneigh(inFeaturesSubset))
# #inFeaturesSubsetA.nb

# ## Create a binary weighted neighbors list
# inFeaturesSubset.listb <- nb2listw(inFeaturesSubset.nb,style="B")
# # creating neighborhood list
# inFeaturesSubset.listw <- nb2listw(inFeaturesSubset.nb,style="W")

# %% [markdown]
# #### Experiment

# %%
#Row names
rn = row.names(inFeaturesSubsetA)
# xy.nb <- dnearneigh(xy, 0, .2, row.names=rn) #not sure about 100
# xy.nb

# creating neighborhood 
#xy <- coordinates(inFeaturesSubsetA)
inFeaturesSubsetA.nb <- dnearneigh(inFeaturesSubsetA, 0, .1, row.names=rn)
#inFeaturesSubsetA.nb

## Select features with at least one neighbor.
inFeaturesSubset <- inFeaturesSubsetA[card(inFeaturesSubsetA.nb) >= 1, ]

## Identify the neighbors of each feature having at least one neighbor.
inFeaturesSubset.nb <- dnearneigh(inFeaturesSubset, 0, .1, row.names=rn)
#inFeaturesSubsetA.nb

## Create a binary weighted neighbors list
inFeaturesSubset.listb <- nb2listw(inFeaturesSubset.nb,style="B")
# creating neighborhood list
inFeaturesSubset.listw <- nb2listw(inFeaturesSubset.nb,style="W")

# %%
inFeaturesSubset.nb
# Out:
# Neighbour list object:
# Number of regions: 644
# Number of nonzero links: 414092
# Percentage nonzero weights: 99.84472
# Average number of links: 643

# %% [markdown]
# ## Analysis Variables
#
# Configure the variables to analyze.
#
# In this practice, the dependent variable is 'y12_M082_1' (acres of irrigated land as percent of land in farms acreage (year 2012)) and the explanatory variable will be 'GRIDCODE' (mean annual rainfall 1990-2009).

# %%
## Response variable.
YVar <- inFeaturesSubset$Rank_0_1

## Explanatory variable.
EXVar <- inFeaturesSubset$sky
#For multi-linear
#EXVar <- inFeaturesSubset$sky+inFeaturesSubset$wall+inFeaturesSubset$building+inFeaturesSubset$fence+inFeaturesSubset$tree+inFeaturesSubset$plant+inFeaturesSubset$road+inFeaturesSubset$sidewalk+inFeaturesSubset$streetligh+inFeaturesSubset$signboard+inFeaturesSubset$person+inFeaturesSubset$bicycle+inFeaturesSubset$car+inFeaturesSubset$truck

# %% [markdown]
# ## Examine Characteristics of Variables
#
# Produce a scatterplot of the dependent variable (y-axis) and the explanatory variable (x-axis). What can be observed? Well, it seems that there is some trend manifesting here. The Shapiro test however indicates the dependent variable is likely not normal as the null hypothesis can be rejected. Although that's not a huge concern at this point, the dependent variable can be transformed to make it more linear.

# %%
## Scatter plot of model variables.
plot(EXVar,YVar,pch=19,main="% Sky vs Sentiment Ranking",cex.main=.8)

## Conduct a shapiro test.
shapiro.test(as.numeric(YVar))
# Out:
# 	Shapiro-Wilk normality test
#
# data:  as.numeric(YVar)
# W = 0.6055, p-value < 2.2e-16
# Plot with title "% Sky vs Sentiment Ranking"

# %% [markdown]
# Remember, the individual components of the test statistic can be accessed as well.  Take a look at the structure of the test statistic output (i.e., str()).

# %%
#Evaluate structure of test statistic result.
str(shapiro.test(as.numeric(YVar)))
# Out:
# List of 4
#  $ statistic: Named num 0.605
#   ..- attr(*, "names")= chr "W"
#  $ p.value  : num 8.07e-36
#  $ method   : chr "Shapiro-Wilk normality test"
#  $ data.name: chr "as.numeric(YVar)"
#  - attr(*, "class")= chr "htest"

# %% [markdown]
# Thus, the individual components of the test statistic results can be accessed as we did in earlier modules.

# %%
#Access statistic attribute by name.
print(shapiro.test(as.numeric(YVar))$statistic)

#Access statistic attribute by index.
print(shapiro.test(as.numeric(YVar))[1])
# Out:
#         W
# 0.6054977
# $statistic
#         W
# 0.6054977

# %% [markdown]
# ### Transform the Dependent Variable
#
# Here, the dependent variable is powered to adjust the distribution.

# %%
### Power transformation applied.
lambdapwr <- (1/3)
y.YVar <- as.numeric(YVar)^(lambdapwr)
#y.YVar

# %%
## Scatterplot of model variables.
plot(EXVar,y.YVar,pch=19,main="% Sky vs Sentiment Ranking",cex.main=.8)

## Histogram of dependent variable.
hist(y.YVar)
# Out:
# Plot with title "% Sky vs Sentiment Ranking"
# Plot with title "Histogram of y.YVar"

# %% [markdown]
# ### Shapiro Test
#
# Test the dependent variable again and produce a Q-Q plot.  This time it looks like the null hypothesis is not as easily rejected. Feel free to experiment with the transformation and investigate whether a better transformation can be found. If you do find a better transformation, post it to the discussion page!

# %%
## Shapiro test.
shapiro.test(y.YVar)
shapiro.test(EXVar)

## Default S3 method:
qqnorm(y.YVar, main = "Normal Q-Q Plot",
       xlab = "Theoretical Quantiles", ylab = "Sample Quantiles",
       plot.it = TRUE, datax = FALSE)

qqline(y.YVar, datax = FALSE)

qqplot(EXVar, y.YVar, plot.it = TRUE, xlab = deparse(substitute(x)),
       ylab = deparse(substitute(y.YVar)))
# Out:
# 	Shapiro-Wilk normality test
#
# data:  y.YVar
# W = 0.6055, p-value < 2.2e-16
# 	Shapiro-Wilk normality test
#
# data:  EXVar
# W = 0.93367, p-value = 2.65e-16
# Plot with title "Normal Q-Q Plot"
# plot without title

# %% [markdown]
# # Normal Probability Models
#
# ## Regular (OLS) Regression
#
# Let's first conduct a OLS linear regression.
#
# Remember, OLS can be called using R's lm() function.  After the function is applied, the resid() function can be called to retrieve the modeled residuals.  Test the residuals to see if normality can be accepted...looks good to me.

# %%
# ## Simple OLS.
# YVar.lm <- lm(y.YVar ~ EXVar)

# ## OLS summary.
# summary(YVar.lm)

# ## Shapiro test.
# shapiro.test(resid(YVar.lm))

# %% [markdown]
# ## Multi Linear Regression

# %%
YVar.lm <- lm(y.YVar ~ inFeaturesSubset$sky+inFeaturesSubset$wall+inFeaturesSubset$building+inFeaturesSubset$fence+inFeaturesSubset$tree+inFeaturesSubset$plant+inFeaturesSubset$road+inFeaturesSubset$sidewalk+inFeaturesSubset$streetligh+inFeaturesSubset$signboard+inFeaturesSubset$person+inFeaturesSubset$bicycle+inFeaturesSubset$car+inFeaturesSubset$truck)
#summary(YVar.lm)

## OLS summary.
summary(YVar.lm)

## Shapiro test.
shapiro.test(resid(YVar.lm))
# Out:
# Call:
# lm(formula = y.YVar ~ inFeaturesSubset$sky + inFeaturesSubset$wall +
#     inFeaturesSubset$building + inFeaturesSubset$fence + inFeaturesSubset$tree +
#     inFeaturesSubset$plant + inFeaturesSubset$road + inFeaturesSubset$sidewalk +
#     inFeaturesSubset$streetligh + inFeaturesSubset$signboard +
#     inFeaturesSubset$person + inFeaturesSubset$bicycle + inFeaturesSubset$car +
#     inFeaturesSubset$truck)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.94835 -0.10411  0.05165  0.22366  1.02522
#
# Coefficients:
#                             Estimate Std. Error t value Pr(>|t|)
# (Intercept)                  1.18555    0.10588  11.198  < 2e-16 ***
# inFeaturesSubset$sky        -1.64132    0.09086 -18.065  < 2e-16 ***
# inFeaturesSubset$wall        0.15194    0.12112   1.254 0.210156
# inFeaturesSubset$building   -0.24653    0.08295  -2.972 0.003070 **
# inFeaturesSubset$fence      -0.52830    0.16898  -3.126 0.001851 **
# inFeaturesSubset$tree        0.09712    0.08815   1.102 0.270965
# inFeaturesSubset$plant      -0.26808    0.06746  -3.974 7.88e-05 ***
# inFeaturesSubset$road       -0.10645    0.09329  -1.141 0.254240
# inFeaturesSubset$sidewalk    0.60570    0.07266   8.336 4.86e-16 ***
# inFeaturesSubset$streetligh -0.34810    0.09017  -3.861 0.000125 ***
# inFeaturesSubset$signboard   0.91038    0.69180   1.316 0.188663
# inFeaturesSubset$person      0.11512    0.07766   1.482 0.138731
# inFeaturesSubset$bicycle     0.14236    0.07164   1.987 0.047336 *
# inFeaturesSubset$car        -0.15937    0.08410  -1.895 0.058560 .
# inFeaturesSubset$truck       0.03515    0.15488   0.227 0.820537
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.3091 on 629 degrees of freedom
# Multiple R-squared:  0.5927,	Adjusted R-squared:  0.5837
# F-statistic: 65.39 on 14 and 629 DF,  p-value: < 2.2e-16
# 	Shapiro-Wilk normality test
#
# data:  resid(YVar.lm)
# W = 0.92224, p-value < 2.2e-16

# %% [markdown]
# ### Test Residuals for Autocorrelation
#
# Next, test the residuals for presence of spatial autocorrelation.  How can this result be interpreted? Perhaps there is some autocorrelation at work in the residuals. If that's the case, then the assumptions of OLS have been violated.

# %%
## Retrieve residuals.
YVar.lm.res <- residuals(YVar.lm)

## Apply Moran test.
moran.test(YVar.lm.res, inFeaturesSubset.listb)
# Out:
# 	Moran I test under randomisation
#
# data:  YVar.lm.res
# weights: inFeaturesSubset.listb
#
# Moran I statistic standard deviate = Inf, p-value < 2.2e-16
# alternative hypothesis: greater
# sample estimates:
# Moran I statistic       Expectation          Variance
#       -0.00155521       -0.00155521        0.00000000

# %% [markdown]
# ## Spatial Simultaneous Autoregressive (SAR) Model
#
# The SAR specification builds upon the OLS specification in that it accounts for the spatial weights among the features (row standardized - W) as an explanatory variable and estimates a coefficient for spatial autocorrelation (rho). The errorsarlm() function (spdep library) can be applied to specify a SAR model.
#
# The syntax for errorsarlm() is:
#
#     errorsarlm(formula, data=list(), listw, na.action, weights=NULL,
#     etype="error", method="eigen", quiet=NULL, zero.policy=NULL,
#     interval = NULL, tol.solve=1.0e-10, trs=NULL, control=list())
#
#
# The errorsarlm() function requires the dependent and independent variables in the form of a 'formula' as well as the neighborhood list 'listw'.
#
# Conduct the SAR analysis below.  Are there any indications of positive spatial autocorrelation?  Does the SAR model improve upon the amount of variance that is accounted for? How can you tell?
#
# Note that the standard errors in the OLS specification are lower than in the SAR specification. This shows that not accounting for spatial autocorrelation makes the OLS results falsely appear to be stronger than they really are!
#
# Finally, examine normality of the residuals. There is still an indication of non-normality, but not as extreme as before.

# %%
## SAR model.
#YVar.sar1 <- errorsarlm(y.YVar ~ EXVar, listw=inFeaturesSubset.listw)

YVar.sar1 <- errorsarlm(y.YVar ~ inFeaturesSubset$sky+inFeaturesSubset$wall+inFeaturesSubset$building+inFeaturesSubset$fence+inFeaturesSubset$tree+inFeaturesSubset$plant+inFeaturesSubset$road+inFeaturesSubset$sidewalk+inFeaturesSubset$streetligh+inFeaturesSubset$signboard+inFeaturesSubset$person+inFeaturesSubset$bicycle+inFeaturesSubset$car+inFeaturesSubset$truck, listw=inFeaturesSubset.listw)


## Summary of SAR model.
summary(YVar.sar1)

## obtain the model residuals.
YVar.sar1.res <- residuals(YVar.sar1)

## Conduct the Shapiro test.
shapiro.test(YVar.sar1.res)
# Out:
# Warning message in errorsarlm(y.YVar ~ inFeaturesSubset$sky + inFeaturesSubset$wall + :
# "inversion of asymptotic covariance matrix failed for tol.solve = 2.22044604925031e-16
#   reciprocal condition number = 8.11525e-17 - using numerical Hessian."
# Call:
# errorsarlm(formula = y.YVar ~ inFeaturesSubset$sky + inFeaturesSubset$wall +
#     inFeaturesSubset$building + inFeaturesSubset$fence + inFeaturesSubset$tree +
#     inFeaturesSubset$plant + inFeaturesSubset$road + inFeaturesSubset$sidewalk +
#     inFeaturesSubset$streetligh + inFeaturesSubset$signboard +
#     inFeaturesSubset$person + inFeaturesSubset$bicycle + inFeaturesSubset$car +
#     inFeaturesSubset$truck, listw = inFeaturesSubset.listw)
#
# Residuals:
#         Min          1Q      Median          3Q         Max
# -1.1197e-03 -1.2293e-04  6.0985e-05  2.6408e-04  1.2105e-03
#
# Type: error
# Coefficients: (asymptotic standard errors)
#                              Estimate Std. Error  z value  Pr(>|z|)
# (Intercept)                  1.185550   0.103941  11.4060 < 2.2e-16
# inFeaturesSubset$sky        -1.641316   0.089793 -18.2789 < 2.2e-16
# inFeaturesSubset$wall        0.151935   0.119701   1.2693  0.204339
# inFeaturesSubset$building   -0.246530   0.081974  -3.0074  0.002635
# inFeaturesSubset$fence      -0.528299   0.167000  -3.1635  0.001559
# inFeaturesSubset$tree        0.097121   0.087114   1.1149  0.264905
# inFeaturesSubset$plant      -0.268085   0.066667  -4.0212 5.790e-05
# inFeaturesSubset$road       -0.106455   0.092194  -1.1547  0.248221
# inFeaturesSubset$sidewalk    0.605700   0.071814   8.4343 < 2.2e-16
# inFeaturesSubset$streetligh -0.348100   0.089112  -3.9063 9.372e-05
# inFeaturesSubset$signboard   0.910383   0.683692   1.3316  0.183002
# inFeaturesSubset$person      0.115117   0.076746   1.5000  0.133618
# inFeaturesSubset$bicycle     0.142362   0.070801   2.0107  0.044354
# inFeaturesSubset$car        -0.159370   0.083118  -1.9174  0.055189
# inFeaturesSubset$truck       0.035149   0.153062   0.2296  0.818372
#
# Lambda: -642.24, LR test value: 38.961, p-value: 4.3231e-10
# Approximate (numerical Hessian) standard error: 0.018304
#     z-value: -35087, p-value: < 2.22e-16
# Wald statistic: 1231100000, p-value: < 2.22e-16
#
# Log likelihood: -130.6233 for error model
# ML residual variance (sigma squared): 1.301e-07, (sigma: 0.00036069)
# Number of observations: 644
# Number of parameters estimated: 17
# AIC: 295.25, (AIC for lm: 332.21)
# 	Shapiro-Wilk normality test
#
# data:  YVar.sar1.res
# W = 0.92224, p-value < 2.2e-16

# %% [markdown]
# ### Test Residuals for Autocorrelation
#
# Test the SAR residuals for presence of spatial autocorrelation.  How does this result differ from the Moran test applied to the OLS residuals?

# %%
## Apply Moran test to SAR residuals.
moran.test(YVar.sar1.res, inFeaturesSubset.listb)
# Out:
# 	Moran I test under randomisation
#
# data:  YVar.sar1.res
# weights: inFeaturesSubset.listb
#
# Moran I statistic standard deviate = -Inf, p-value = 1
# alternative hypothesis: greater
# sample estimates:
# Moran I statistic       Expectation          Variance
#       -0.00155521       -0.00155521        0.00000000

# %% [markdown]
# ### Visualize the Fitted Values (SAR) Model
#
# Visualize the fitted SAR values, being sure that the values are back-transformed into their original measurement units prior to mapping.

# %% [markdown]
# #### Back-Transformation
#
# Back-transformation is the process of reversing a transformation that was previously applied to a dataset.
#
# Recall that earlier we transformed 'Y.Var' by powering to 'lambdapwr' (which was 1/3 in the earlier example).  To back-transform the fitted values, we will therefore need to power them to 1/'lambdapwr' (e.g., 1/(1/3) per our earlier example.

# %%
## Back-transform fitted values into original measurement units.
bt.YVar.sar1 <- YVar.sar1$fitted^(1/lambdapwr)

# %% [markdown]
# Now, map the back-transformed fitted values.

# %%
## Classify the variable.
numcat <- 5
cate <- classIntervals(bt.YVar.sar1, numcat, style="quantile")

## Assign colors to categories.
pal <- brewer.pal(numcat,"Reds")
cols <- findColours(cate,pal)

## Visualize fitted SAR values.
plot(inFeaturesSubset, col=cols, lwd=.2,main="Fitted Values - SAR Model",cex.main=.8)
brks <- round(cate$brks,3)
leg <- paste(brks[-(numcat+1)], brks[-1], sep=" - ")
legend("bottomleft", fill=pal, legend=leg, bty="n",title="Fitted Values",cex=.7)
# Out:
# Plot with title "Fitted Values - SAR Model"

# %% [markdown]
# ### Examine Correlation Among the Variables
#
# Next, examine the correlation between the dependent and independent variables using the Pearson Correlation Coefficient. This can be done using R's corr() function. As can be observed, the correlation is negative, meaning that as one variable increases, the other decreases. However, given that spatial autocorrelation was detected in the model, this is suspect and can indicated that spatial autocorrelation is affecting the variables themselves. Given this, we can now examine each of the variables for spatial autocorrelation.

# %%
## Calculate Pearson product moment correlation coefficient.
paste("Pearson Correlation = ",cor(y.YVar, EXVar))
# Out:
# [1] "Pearson Correlation =  -0.649959912979008"

# %% [markdown]
# ## Estimate SAR Model for Each Variable
#
# This time, let's apply a SAR model to both variables (dependent and explanatory) individually and simply examine the impact of the spatial weights. The rho or lambda parameter estimated by the SAR models can then be returned. Note that for both variables, rho (lambda) is significant, indicating spatial autocorrelation is at work in both of the variables.

# %%
## Estimate SAR autocorrelation parameter for Y variable.
YVar.sar2 <- errorsarlm(y.YVar ~ 1, listw=inFeaturesSubset.listw)
summary(YVar.sar2)
paste("Lambda = ",YVar.sar2$lambda)


## Estimate SAR autocorrelation parameter for X variable.
EXVar.sar2 <- errorsarlm(EXVar ~ 1, listw=inFeaturesSubset.listw)
summary(EXVar.sar2)
paste("Lambda = ",EXVar.sar2$lambda)
# Out:
# Call:errorsarlm(formula = y.YVar ~ 1, listw = inFeaturesSubset.listw)
#
# Residuals:
#         Min          1Q      Median          3Q         Max
# -0.00076179 -0.00076179  0.00042036  0.00042036  0.00042036
#
# Type: error
# Coefficients: (asymptotic standard errors)
#               Estimate Std. Error  z value  Pr(>|z|)
# (Intercept) 6.4441e-01 3.4667e-08 18588679 < 2.2e-16
#
# Lambda: -642.24, LR test value: 29.85, p-value: 4.6681e-08
# Asymptotic standard error: 0.53727
#     z-value: -1195.4, p-value: < 2.22e-16
# Wald statistic: 1428900, p-value: < 2.22e-16
#
# Log likelihood: -424.4376 for error model
# ML residual variance (sigma squared): 3.2023e-07, (sigma: 0.00056589)
# Number of observations: 644
# Number of parameters estimated: 3
# AIC: 854.88, (AIC for lm: 882.73)
# [1] "Lambda =  -642.239875630411"
# Warning message in errorsarlm(EXVar ~ 1, listw = inFeaturesSubset.listw):
# "inversion of asymptotic covariance matrix failed for tol.solve = 2.22044604925031e-16
#   reciprocal condition number = 1.40214e-17 - using numerical Hessian."
# Warning message in sqrt(fdHess[1, 1]):
# "NaNs produced"
# Call:errorsarlm(formula = EXVar ~ 1, listw = inFeaturesSubset.listw)
#
# Residuals:
#         Min          1Q      Median          3Q         Max
# -2.1987e-04 -1.1929e-04 -5.4894e-05  1.2405e-04  4.1066e-04
#
# Type: error
# Coefficients: (asymptotic standard errors)
#               Estimate Std. Error  z value  Pr(>|z|)
# (Intercept) 3.1598e-01 9.4244e-09 33527849 < 2.2e-16
#
# Lambda: -642.5, LR test value: 32.738, p-value: 1.0545e-08
# Approximate (numerical Hessian) standard error: NaN
#     z-value: NaN, p-value: NA
# Wald statistic: NaN, p-value: NA
#
# Log likelihood: 143.881 for error model
# ML residual variance (sigma squared): 2.3686e-08, (sigma: 0.0001539)
# Number of observations: 644
# Number of parameters estimated: 3
# AIC: -281.76, (AIC for lm: -251.02)
# [1] "Lambda =  -642.501475751209"

# %% [markdown]
# ### Adjust Variables for Spatial Autocorrelation
#
# Use the rho (lambda) parameters estimate above to adjust the dependent and explanatory variables for autocorrelation. This task can be accomplished is illustrated below. Basically, the dependent and independent variables are adjusted by subtracting them by the product of rho (lambda) and the spatial weights matrix (as a lag vector). The lag vector can be created using the lag.listw() function ('spdep' library). After the adjustment is made, re-assess the correlation between the adjusted variables.
#
# Note that after adjusting for spatial autocorrelation in each variable, the correlation is very much reduced from that computed earlier based on the unadjusted variables. Therefore, it is clear that if spatial autocorrelation was not accounted for, the correlation would appear to be much higher than it actually is.

# %%
## Adjust for spatial autocorrelation.
YVar.sa <- y.YVar - YVar.sar2$lambda * lag.listw(inFeaturesSubset.listw,y.YVar)
EXVar.sa <- EXVar - EXVar.sar2$lambda * lag.listw(inFeaturesSubset.listw,EXVar)

## Recompute adjusted Pearson product moment correlation coefficient.
cor(YVar.sa,EXVar.sa)
# Out:
# [1] -0.6499599

# %% [markdown]
# ### Spatially Adjusted OLS
#
# Use the variables adjusted for spatial autocorrelation ('YVar.sa' and 'EXVar.sa') in a new OLS model. How do the results differ from the linear model estimated earlier with unadjusted variables?

# %%
## Apply linear model after adjusting for spatial autocorrelation.
YVar.lm.sa <- lm(YVar.sa ~ EXVar.sa)

## Summarize model.
summary(YVar.lm.sa)
# Out:
# Call:
# lm(formula = YVar.sa ~ EXVar.sa)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -1.186e-03 -3.496e-04  7.741e-05  2.838e-04  1.402e-03
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 900.4460    22.4244   40.16   <2e-16 ***
# EXVar.sa     -2.3898     0.1103  -21.67   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.0004307 on 642 degrees of freedom
# Multiple R-squared:  0.4224,	Adjusted R-squared:  0.4215
# F-statistic: 469.6 on 1 and 642 DF,  p-value: < 2.2e-16

# %% [markdown]
# ### Evaluate Adjusted Regression Residuals for Normality
#
# Apply normality diagnostics to test the residuals of the adjusted linear model.  Can the null hypothesis that the residuals are normally distributed be rejected at the 0.05 confidence level?

# %%
## Compute normality diagnostics.
shapiro.test(residuals(YVar.lm.sa))
# Out:
# 	Shapiro-Wilk normality test
#
# data:  residuals(YVar.lm.sa)
# W = 0.95545, p-value = 4.775e-13

# %% [markdown]
# ### Evaluate Adjusted Regression Residuals for Spatial Autocorrelation
#
# Test the residuals to see if spatial autocorrelation was effectively treated by the adjustment process.  Well, was it? How can you tell?

# %%
## Apply Moran test to residuals.
moran.test(residuals(YVar.lm.sa), inFeaturesSubset.listb)
# Out:
# 	Moran I test under randomisation
#
# data:  residuals(YVar.lm.sa)
# weights: inFeaturesSubset.listb
#
# Moran I statistic standard deviate = -Inf, p-value = 1
# alternative hypothesis: greater
# sample estimates:
# Moran I statistic       Expectation          Variance
#       -0.00155521       -0.00155521        0.00000000

# %% [markdown]
# # SAVE YOUR NOTEBOOK, then `File > Close and Halt`

# %% [markdown]
# ![copyright.png](attachment:copyright.png)
